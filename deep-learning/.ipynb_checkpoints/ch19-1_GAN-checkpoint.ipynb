# %% [markdown]
# # DCGAN
#
# https://arxiv.org/pdf/1511.06434.pdf
#
# ### GAN
#  - 생성자와 판별자가 경쟁하며 가짜 데이터를 생성하는 네트워크
#
#
# ![image.png](data:image/png;base64,...)

# %%
#-*- coding: utf-8 -*-

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

# %% [markdown]
# ## 생성자
# - 작은 이미지를 점점 늘려가면서 conv레이어를 통과함
# - 7x7 최초이미지 2배씩 증가 (UnSampling2D로 뻥튀기시킴)
# - 풀링X
# - 패딩: 원본이미지와 입출력 크기를 동일하게 하기 위해 설정(padding='same')
# - 활성화함수 tanh: 값을 -1 ~ 1 범위로 출력하므로, 진짜이미지도 -1~1로 출력하도록 수정
# - BN: 입력평균 = 0, 분산=1되도록 재배치, 다음층으로 입력될 값을 일정하게 재배치하는 역할

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# %% [markdown]
# ## 판별자
#
# * loss: Binary CEE(진짜/가짜 판단),
# * optimizer : adam
# * stride = 2
#     - 가로, 세로 크기가 더 줄어들어 새로운 필터를 적용한 효과가 생김
#     - 드롭아웃이나 풀링처럼 새로운 필터를 적용한 효과가 생김
# * discriminator.trainable = False : 판별자는 학습되지 않도록함

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# %% [markdown]
# ## GAN 모델

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %% [markdown]
# ## 신경망 실행
#
# **[참고]**
# - model.fit: epochs, batch_size를 넘겨줌
# - model.train_on_batch: 데이터를 모두 활용해서 gradient vector를 계산해서 업데이트

# %%
#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기


  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 
  # 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  (X_train, _), (_, _) = mnist.load_data()  
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  # 픽셀값은 0에서 255사이의 값입니다. 
  # 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 
  # 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  X_train = (X_train - 127.5) / 127.5  
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# epoch:0  d_loss:0.7053  g_loss:0.6912
# epoch:1  d_loss:0.4624  g_loss:0.3282
# epoch:2  d_loss:0.5685  g_loss:0.1025
# epoch:3  d_loss:0.6585  g_loss:0.0836
# epoch:4  d_loss:0.5768  g_loss:0.1651
# epoch:5  d_loss:0.5088  g_loss:0.4209
# epoch:6  d_loss:0.4876  g_loss:0.6969
# epoch:7  d_loss:0.5092  g_loss:0.8694
# epoch:8  d_loss:0.4967  g_loss:0.8961
# epoch:9  d_loss:0.4862  g_loss:0.8712
# epoch:10  d_loss:0.4177  g_loss:0.7858
# epoch:11  d_loss:0.4397  g_loss:0.8091
# epoch:12  d_loss:0.4827  g_loss:0.8660
# epoch:13  d_loss:0.4752  g_loss:0.9141
# epoch:14  d_loss:0.5707  g_loss:0.9766
# epoch:15  d_loss:0.4734  g_loss:1.0490
# epoch:16  d_loss:0.4018  g_loss:1.0544
# epoch:17  d_loss:0.6223  g_loss:0.7835
# epoch:18  d_loss:0.5634  g_loss:0.6439
# epoch:19  d_loss:0.4578  g_loss:0.7305
# epoch:20  d_loss:0.4222  g_loss:0.7998
# epoch:21  d_loss:0.5037  g_loss:0.8303
# epoch:22  d_loss:0.5159  g_loss:0.6801
# epoch:23  d_loss:0.4585  g_loss:0.6260
# epoch:24  d_loss:0.4518  g_loss:0.6764
# epoch:25  d_loss:0.4702  g_loss:0.7217
# epoch:26  d_loss:0.5175  g_loss:0.7298
# epoch:27  d_loss:0.4800  g_loss:0.6054
# epoch:28  d_loss:0.4987  g_loss:0.5645
# epoch:29  d_loss:0.5261  g_loss:0.5572
# epoch:30  d_loss:0.4582  g_loss:0.6454
# epoch:31  d_loss:0.4867  g_loss:0.6948
# epoch:32  d_loss:0.4311  g_loss:0.6024
# epoch:33  d_loss:0.4341  g_loss:0.6576
# epoch:34  d_loss:0.3258  g_loss:0.7000
# epoch:35  d_loss:0.3845  g_loss:0.8166
# epoch:36  d_loss:0.4371  g_loss:0.5796
# epoch:37  d_loss:0.3581  g_loss:0.7300
# epoch:38  d_loss:0.3316  g_loss:0.9427
# epoch:39  d_loss:0.2305  g_loss:1.2067
# epoch:40  d_loss:0.3244  g_loss:1.1976
# epoch:41  d_loss:0.4107  g_loss:0.9135
# epoch:42  d_loss:0.3574  g_loss:0.7574
# epoch:43  d_loss:0.2251  g_loss:1.1985
# epoch:44  d_loss:0.1936  g_loss:1.3848
# epoch:45  d_loss:0.1420  g_loss:2.2035
# epoch:46  d_loss:0.2845  g_loss:1.6620
# epoch:47  d_loss:0.2128  g_loss:1.2194
# epoch:48  d_loss:0.2397  g_loss:1.2229
# epoch:49  d_loss:0.2679  g_loss:1.2943
# epoch:50  d_loss:0.2881  g_loss:1.5856
# epoch:51  d_loss:0.4071  g_loss:2.1272
# epoch:52  d_loss:0.3593  g_loss:2.1920
# epoch:53  d_loss:0.1796  g_loss:2.0352
# epoch:54  d_loss:0.1097  g_loss:2.1025
# epoch:55  d_loss:0.1120  g_loss:2.7605
# epoch:56  d_loss:0.1259  g_loss:2.5663
# epoch:57  d_loss:0.1922  g_loss:3.0521
# epoch:58  d_loss:0.1687  g_loss:3.5564
# epoch:59  d_loss:0.3181  g_loss:2.9929
# epoch:60  d_loss:0.6235  g_loss:2.5806
# epoch:61  d_loss:0.5167  g_loss:3.2252
# epoch:62  d_loss:0.8606  g_loss:2.7583
# epoch:63  d_loss:0.6304  g_loss:2.7846
# epoch:64  d_loss:0.4641  g_loss:3.4193
# epoch:65  d_loss:0.5559  g_loss:3.4860
# epoch:66  d_loss:0.3158  g_loss:3.2990
# epoch:67  d_loss:0.1551  g_loss:3.7973
# epoch:68  d_loss:0.1094  g_loss:4.0131
# epoch:69  d_loss:0.3920  g_loss:3.4914
# epoch:70  d_loss:0.5301  g_loss:2.3301
# epoch:71  d_loss:0.3379  g_loss:2.0526
# epoch:72  d_loss:0.5563  g_loss:1.8162
# epoch:73  d_loss:0.3521  g_loss:2.2045
# epoch:74  d_loss:0.8037  g_loss:0.9947
# epoch:75  d_loss:0.9769  g_loss:0.7737
# epoch:76  d_loss:0.6728  g_loss:1.5192
# epoch:77  d_loss:0.8401  g_loss:1.8762
# epoch:78  d_loss:0.7607  g_loss:1.4776
# epoch:79  d_loss:0.5059  g_loss:1.9477
# epoch:80  d_loss:0.3668  g_loss:2.8898
# epoch:81  d_loss:0.2609  g_loss:4.0251
# epoch:82  d_loss:0.1705  g_loss:4.3749
# epoch:83  d_loss:0.1463  g_loss:5.0914
# epoch:84  d_loss:0.2461  g_loss:4.5788
# epoch:85  d_loss:0.5732  g_loss:4.7041
# epoch:86  d_loss:0.3496  g_loss:6.6036
# epoch:87  d_loss:0.6559  g_loss:6.1698
# epoch:88  d_loss:1.0688  g_loss:4.2872
# epoch:89  d_loss:1.2703  g_loss:4.0520
# epoch:90  d_loss:0.8160  g_loss:4.7474
# epoch:91  d_loss:0.9747  g_loss:4.8709
# epoch:92  d_loss:1.3132  g_loss:3.5199
# epoch:93  d_loss:1.1495  g_loss:2.2947
# epoch:94  d_loss:0.8478  g_loss:1.6605
# epoch:95  d_loss:0.5944  g_loss:1.7586
# epoch:96  d_loss:0.5274  g_loss:1.6270
# epoch:97  d_loss:0.3890  g_loss:1.7344
# epoch:98  d_loss:0.3689  g_loss:1.5611
# epoch:99  d_loss:0.4578  g_loss:1.4848
# epoch:100  d_loss:0.4223  g_loss:1.2631
# epoch:101  d_loss:0.3243  g_loss:0.9486
# epoch:102  d_loss:0.2902  g_loss:1.0424
# epoch:103  d_loss:0.4181  g_loss:0.9289
# epoch:104  d_loss:0.3075  g_loss:1.0216
# epoch:105  d_loss:0.3886  g_loss:0.9414
# epoch:106  d_loss:0.3513  g_loss:0.8680
# epoch:107  d_loss:0.3264  g_loss:0.8540
# epoch:108  d_loss:0.4038  g_loss:0.8919
# epoch:109  d_loss:0.3706  g_loss:0.8367
# epoch:110  d_loss:0.3060  g_loss:1.0427
# epoch:111  d_loss:0.3798  g_loss:0.9473
# epoch:112  d_loss:0.3958  g_loss:0.9453
# epoch:113  d_loss:0.4917  g_loss:0.6599
# epoch:114  d_loss:0.6158  g_loss:0.6877
# epoch:115  d_loss:0.5784  g_loss:0.6489
# epoch:116  d_loss:0.5168  g_loss:0.6660
# epoch:117  d_loss:0.5876  g_loss:0.7901
# epoch:118  d_loss:0.6167  g_loss:0.8392
# epoch:119  d_loss:0.4775  g_loss:0.9321
# epoch:120  d_loss:0.6648  g_loss:0.7621
# epoch:121  d_loss:0.7742  g_loss:0.7053
# epoch:122  d_loss:0.8140  g_loss:0.6805
# epoch:123  d_loss:0.7577  g_loss:0.6956
# epoch:124  d_loss:0.6393  g_loss:0.7916
# epoch:125  d_loss:0.9471  g_loss:0.7750
# epoch:126  d_loss:0.7302  g_loss:0.9165
# epoch:127  d_loss:0.6186  g_loss:1.0852
# epoch:128  d_loss:0.6601  g_loss:0.9901
# epoch:129  d_loss:0.6312  g_loss:1.1274
# epoch:130  d_loss:0.5814  g_loss:0.9418
# epoch:131  d_loss:0.5974  g_loss:1.2550
# epoch:132  d_loss:0.5615  g_loss:1.1426
# epoch:133  d_loss:0.4644  g_loss:1.5646
# epoch:134  d_loss:0.4635  g_loss:1.5465
# epoch:135  d_loss:0.4207  g_loss:1.6406
# epoch:136  d_loss:0.4148  g_loss:1.5334
# epoch:137  d_loss:0.3622  g_loss:1.5895
# epoch:138  d_loss:0.3471  g_loss:1.5902
# epoch:139  d_loss:0.3048  g_loss:2.0055
# epoch:140  d_loss:0.3559  g_loss:2.0877
# epoch:141  d_loss:0.3430  g_loss:2.0749
# epoch:142  d_loss:0.3265  g_loss:1.9800
# epoch:143  d_loss:0.3090  g_loss:1.8271
# epoch:144  d_loss:0.3871  g_loss:1.9107
# epoch:145  d_loss:0.3520  g_loss:1.9125
# epoch:146  d_loss:0.3100  g_loss:2.5186
# epoch:147  d_loss:0.6009  g_loss:2.2351
# epoch:148  d_loss:0.6077  g_loss:1.5941
# epoch:149  d_loss:0.6241  g_loss:1.8027
# epoch:150  d_loss:0.5251  g_loss:2.0835
# epoch:151  d_loss:0.6145  g_loss:2.0645
# epoch:152  d_loss:0.8793  g_loss:1.5801
# epoch:153  d_loss:0.6516  g_loss:1.8487
# epoch:154  d_loss:0.6081  g_loss:1.2597
# epoch:155  d_loss:0.8612  g_loss:1.0432
# epoch:156  d_loss:0.8305  g_loss:1.1729
# epoch:157  d_loss:0.6680  g_loss:1.3762
# epoch:158  d_loss:0.6142  g_loss:1.5280
# epoch:159  d_loss:0.5250  g_loss:1.6854
# epoch:160  d_loss:0.6758  g_loss:1.5756
# epoch:161  d_loss:0.6560  g_loss:1.4169
# epoch:162  d_loss:0.5010  g_loss:1.5767
# epoch:163  d_loss:0.5546  g_loss:1.5427
# epoch:164  d_loss:0.5656  g_loss:1.4414
# epoch:165  d_loss:0.4690  g_loss:1.4477
# epoch:166  d_loss:0.4798  g_loss:1.5125
# epoch:167  d_loss:0.4942  g_loss:1.4995
# epoch:168  d_loss:0.4150  g_loss:1.7226
# epoch:169  d_loss:0.5251  g_loss:1.6080
# epoch:170  d_loss:0.4443  g_loss:1.6885
# epoch:171  d_loss:0.3857  g_loss:1.4516
# epoch:172  d_loss:0.4382  g_loss:1.3694
# epoch:173  d_loss:0.3750  g_loss:1.5975
# epoch:174  d_loss:0.4310  g_loss:1.5818
# epoch:175  d_loss:0.4175  g_loss:1.6783
# epoch:176  d_loss:0.4980  g_loss:1.7101
# epoch:177  d_loss:0.4214  g_loss:1.8917
# epoch:178  d_loss:0.2952  g_loss:1.7884
# epoch:179  d_loss:0.3436  g_loss:1.8297
# epoch:180  d_loss:0.3918  g_loss:1.5399
# epoch:181  d_loss:0.3627  g_loss:1.6501
# epoch:182  d_loss:0.3938  g_loss:1.5304
# epoch:183  d_loss:0.3049  g_loss:1.5660
# epoch:184  d_loss:0.3157  g_loss:1.5388
# epoch:185  d_loss:0.4754  g_loss:1.5904
# epoch:186  d_loss:0.3818  g_loss:1.7277
# epoch:187  d_loss:0.4105  g_loss:1.6916
# epoch:188  d_loss:0.5540  g_loss:1.4948
# epoch:189  d_loss:0.4657  g_loss:1.2794
# epoch:190  d_loss:0.3397  g_loss:1.7345
# epoch:191  d_loss:0.5650  g_loss:1.3928
# epoch:192  d_loss:0.4868  g_loss:1.3363
# epoch:193  d_loss:0.5192  g_loss:1.1153
# epoch:194  d_loss:0.5667  g_loss:1.1951
# epoch:195  d_loss:0.5422  g_loss:1.1721
# epoch:196  d_loss:0.5726  g_loss:1.2922
# epoch:197  d_loss:0.5390  g_loss:1.2716
# epoch:198  d_loss:0.4995  g_loss:1.4487
# epoch:199  d_loss:0.6387  g_loss:1.2081
# epoch:200  d_loss:0.5986  g_loss:1.2838
# epoch:201  d_loss:0.5911  g_loss:1.1945
# epoch:202  d_loss:0.6854  g_loss:1.3902
# epoch:203  d_loss:0.4425  g_loss:1.5235
# epoch:204  d_loss:0.5107  g_loss:1.7507
# epoch:205  d_loss:0.5589  g_loss:1.3884
# epoch:206  d_loss:0.5666  g_loss:1.3408
# epoch:207  d_loss:0.4825  g_loss:1.5749
# epoch:208  d_loss:0.5987  g_loss:1.5176
# epoch:209  d_loss:0.3679  g_loss:1.8125
# epoch:210  d_loss:0.4674  g_loss:1.8195
# epoch:211  d_loss:0.4005  g_loss:2.1283
# epoch:212  d_loss:0.4651  g_loss:2.0840
# epoch:213  d_loss:0.4695  g_loss:2.3782
# epoch:214  d_loss:0.4841  g_loss:1.6195
# epoch:215  d_loss:0.4650  g_loss:1.5806
# epoch:216  d_loss:0.4105  g_loss:2.1708
# epoch:217  d_loss:0.3621  g_loss:1.9915
# epoch:218  d_loss:0.4389  g_loss:2.5023
# epoch:219  d_loss:0.5199  g_loss:2.5863
# epoch:220  d_loss:0.4973  g_loss:2.2036
# epoch:221  d_loss:0.5616  g_loss:1.9596
# epoch:222  d_loss:0.5296  g_loss:1.8407
# epoch:223  d_loss:0.5797  g_loss:1.7251
# epoch:224  d_loss:0.5967  g_loss:1.8066
# epoch:225  d_loss:0.4206  g_loss:1.9921
# epoch:226  d_loss:0.4967  g_loss:1.6578
# epoch:227  d_loss:0.5897  g_loss:1.9906
# epoch:228  d_loss:0.5204  g_loss:1.9583
# epoch:229  d_loss:0.4616  g_loss:1.8872
# epoch:230  d_loss:0.5688  g_loss:1.6432
# epoch:231  d_loss:0.5823  g_loss:1.8290
# epoch:232  d_loss:0.6744  g_loss:1.5077
# epoch:233  d_loss:0.6242  g_loss:1.4184
# epoch:234  d_loss:0.6635  g_loss:1.2393
# epoch:235  d_loss:0.4901  g_loss:1.3324
# epoch:236  d_loss:0.5277  g_loss:1.5792
# epoch:237  d_loss:0.5251  g_loss:1.7064
# epoch:238  d_loss:0.5730  g_loss:1.5403
# epoch:239  d_loss:0.4673  g_loss:1.5795
# epoch:240  d_loss:0.5066  g_loss:1.5169
# epoch:241  d_loss:0.6305  g_loss:1.3734
# epoch:242  d_loss:0.5988  g_loss:1.1242
# epoch:243  d_loss:0.5729  g_loss:1.2020
# epoch:244  d_loss:0.5013  g_loss:1.2995
# epoch:245  d_loss:0.3692  g_loss:1.7572
# epoch:246  d_loss:0.5820  g_loss:1.6989
# epoch:247  d_loss:0.5500  g_loss:1.7105
# epoch:248  d_loss:0.4956  g_loss:1.5953
# epoch:249  d_loss:0.5854  g_loss:1.4136
# epoch:250  d_loss:0.4870  g_loss:1.3313
# epoch:251  d_loss:0.4031  g_loss:1.6177
# epoch:252  d_loss:0.4687  g_loss:1.2348
# epoch:253  d_loss:0.4824  g_loss:1.3445
# epoch:254  d_loss:0.4805  g_loss:1.7003
# epoch:255  d_loss:0.6346  g_loss:1.4798
# epoch:256  d_loss:0.4838  g_loss:2.0030
# epoch:257  d_loss:0.3970  g_loss:2.0667
# epoch:258  d_loss:0.4587  g_loss:1.4822
# epoch:259  d_loss:0.4369  g_loss:1.7682
# epoch:260  d_loss:0.4560  g_loss:1.5832
# epoch:261  d_loss:0.3900  g_loss:1.6402
# epoch:262  d_loss:0.3516  g_loss:1.6268
# epoch:263  d_loss:0.4502  g_loss:1.9218
# epoch:264  d_loss:0.4230  g_loss:2.0116
# epoch:265  d_loss:0.5173  g_loss:1.8314
# epoch:266  d_loss:0.4332  g_loss:1.5756
# epoch:267  d_loss:0.5166  g_loss:1.8626
# epoch:268  d_loss:0.4368  g_loss:1.7488
# epoch:269  d_loss:0.4871  g_loss:1.7114
# epoch:270  d_loss:0.4610  g_loss:1.8817
# epoch:271  d_loss:0.4764  g_loss:1.8922
# epoch:272  d_loss:0.3947  g_loss:2.1610
# epoch:273  d_loss:0.5339  g_loss:1.8472
# epoch:274  d_loss:0.5020  g_loss:1.9457
# epoch:275  d_loss:0.3792  g_loss:1.7990
# epoch:276  d_loss:0.4945  g_loss:1.9121
# epoch:277  d_loss:0.5167  g_loss:2.0402
# epoch:278  d_loss:0.4475  g_loss:2.0591
# epoch:279  d_loss:0.4326  g_loss:2.0058
# epoch:280  d_loss:0.4074  g_loss:2.0083
# epoch:281  d_loss:0.3581  g_loss:2.3696
# epoch:282  d_loss:0.3987  g_loss:2.1217
# epoch:283  d_loss:0.3699  g_loss:2.3881
# epoch:284  d_loss:0.4935  g_loss:2.0312
# epoch:285  d_loss:0.4140  g_loss:1.9288
# epoch:286  d_loss:0.2946  g_loss:2.5237
# epoch:287  d_loss:0.5017  g_loss:2.1808
# epoch:288  d_loss:0.4460  g_loss:1.9125
# epoch:289  d_loss:0.4448  g_loss:1.9418
# epoch:290  d_loss:0.5328  g_loss:1.7886
# epoch:291  d_loss:0.4738  g_loss:2.1631
# epoch:292  d_loss:0.5207  g_loss:1.7105
# epoch:293  d_loss:0.5299  g_loss:1.9307
# epoch:294  d_loss:0.4662  g_loss:1.7394
# epoch:295  d_loss:0.4973  g_loss:1.7600
# epoch:296  d_loss:0.4907  g_loss:1.8903
# epoch:297  d_loss:0.4968  g_loss:1.7499
# epoch:298  d_loss:0.6489  g_loss:1.7675
# epoch:299  d_loss:0.5088  g_loss:1.6111
# epoch:300  d_loss:0.5593  g_loss:1.7123
# epoch:301  d_loss:0.4592  g_loss:2.4969
# epoch:302  d_loss:0.5259  g_loss:1.9165
# epoch:303  d_loss:0.5678  g_loss:2.3626
# epoch:304  d_loss:0.5822  g_loss:1.5053
# epoch:305  d_loss:0.4581  g_loss:1.9749
# epoch:306  d_loss:0.4053  g_loss:1.9005
# epoch:307  d_loss:0.5485  g_loss:1.7422
# epoch:308  d_loss:0.3655  g_loss:2.3266
# epoch:309  d_loss:0.3523  g_loss:2.1015
# epoch:310  d_loss:0.5275  g_loss:2.4099
# epoch:311  d_loss:0.2959  g_loss:2.6166
# epoch:312  d_loss:0.5087  g_loss:1.9922
# epoch:313  d_loss:0.5176  g_loss:1.4589
# epoch:314  d_loss:0.5444  g_loss:1.5822
# epoch:315  d_loss:0.5261  g_loss:1.6761
# epoch:316  d_loss:0.4521  g_loss:1.7383
# epoch:317  d_loss:0.4026  g_loss:2.2832
# epoch:318  d_loss:0.4576  g_loss:2.2465
# epoch:319  d_loss:0.4617  g_loss:2.0041
# epoch:320  d_loss:0.5098  g_loss:2.0927
# epoch:321  d_loss:0.4295  g_loss:1.5225
# epoch:322  d_loss:0.3441  g_loss:1.8212
# epoch:323  d_loss:0.2723  g_loss:1.9019
# epoch:324  d_loss:0.5074  g_loss:1.5294
# epoch:325  d_loss:0.3731  g_loss:1.9133
# epoch:326  d_loss:0.5811  g_loss:1.6823
# epoch:327  d_loss:0.4036  g_loss:2.4200
# epoch:328  d_loss:0.3650  g_loss:2.3484
# epoch:329  d_loss:0.4444  g_loss:2.2199
# epoch:330  d_loss:0.4662  g_loss:2.4204
# epoch:331  d_loss:0.4473  g_loss:1.6080
# epoch:332  d_loss:0.5411  g_loss:1.7367
# epoch:333  d_loss:0.5487  g_loss:1.7978
# epoch:334  d_loss:0.5914  g_loss:1.6733
# epoch:335  d_loss:0.5196  g_loss:1.8589
# epoch:336  d_loss:0.3844  g_loss:2.4344
# epoch:337  d_loss:0.4095  g_loss:2.3900
# epoch:338  d_loss:0.4969  g_loss:2.1029
# epoch:339  d_loss:0.4959  g_loss:2.1976
# epoch:340  d_loss:0.3991  g_loss:1.6795
# epoch:341  d_loss:0.5054  g_loss:1.8312
# epoch:342  d_loss:0.4432  g_loss:1.5283
# epoch:343  d_loss:0.5354  g_loss:1.7905
# epoch:344  d_loss:0.4987  g_loss:1.7238
# epoch:345  d_loss:0.4613  g_loss:2.1629
# epoch:346  d_loss:0.5939  g_loss:1.7167
# epoch:347  d_loss:0.3830  g_loss:1.7962
# epoch:348  d_loss:0.4321  g_loss:1.4548
# epoch:349  d_loss:0.4429  g_loss:1.7404
# epoch:350  d_loss:0.3889  g_loss:1.7303
# epoch:351  d_loss:0.3507  g_loss:2.1419
# epoch:352  d_loss:0.5090  g_loss:1.5586
# epoch:353  d_loss:0.4611  g_loss:2.0054
# epoch:354  d_loss:0.6131  g_loss:1.8732
# epoch:355  d_loss:0.5526  g_loss:1.5012
# epoch:356  d_loss:0.6293  g_loss:1.2686
# epoch:357  d_loss:0.3509  g_loss:2.1578
# epoch:358  d_loss:0.3289  g_loss:2.6632
# epoch:359  d_loss:0.3520  g_loss:2.4260
# epoch:360  d_loss:0.3652  g_loss:2.9768
# epoch:361  d_loss:0.3574  g_loss:2.9472
# epoch:362  d_loss:0.3286  g_loss:2.7702
# epoch:363  d_loss:0.4759  g_loss:2.3072
# epoch:364  d_loss:0.2848  g_loss:2.7268
# epoch:365  d_loss:0.3141  g_loss:2.5792
# epoch:366  d_loss:0.4326  g_loss:2.5350
# epoch:367  d_loss:0.3169  g_loss:2.8979
# epoch:368  d_loss:0.4177  g_loss:2.2647
# epoch:369  d_loss:0.3925  g_loss:2.2033
# epoch:370  d_loss:0.3500  g_loss:2.0409
# epoch:371  d_loss:0.2743  g_loss:1.9579
# epoch:372  d_loss:0.4116  g_loss:2.4927
# epoch:373  d_loss:0.2894  g_loss:2.5921
# epoch:374  d_loss:0.2374  g_loss:2.2363
# epoch:375  d_loss:0.3117  g_loss:2.5858
# epoch:376  d_loss:0.3573  g_loss:2.3141
# epoch:377  d_loss:0.3575  g_loss:2.4085
# epoch:378  d_loss:0.3942  g_loss:2.4358
# epoch:379  d_loss:0.3690  g_loss:2.7498
# epoch:380  d_loss:0.5281  g_loss:2.3513
# epoch:381  d_loss:0.5380  g_loss:2.7007
# epoch:382  d_loss:0.3938  g_loss:2.3502
# epoch:383  d_loss:0.5468  g_loss:2.2264
# epoch:384  d_loss:0.3951  g_loss:2.1254
# epoch:385  d_loss:0.3245  g_loss:2.4796
# epoch:386  d_loss:0.4626  g_loss:1.9449
# epoch:387  d_loss:0.4091  g_loss:1.9524
# epoch:388  d_loss:0.5409  g_loss:1.6571
# epoch:389  d_loss:0.3894  g_loss:1.9483
# epoch:390  d_loss:0.5557  g_loss:1.7219
# epoch:391  d_loss:0.4324  g_loss:1.7636
# epoch:392  d_loss:0.4659  g_loss:1.8669
# epoch:393  d_loss:0.3388  g_loss:1.9496
# epoch:394  d_loss:0.4459  g_loss:1.8234
# epoch:395  d_loss:0.3352  g_loss:2.2236
# epoch:396  d_loss:0.3177  g_loss:2.2057
# epoch:397  d_loss:0.3202  g_loss:2.0775
# epoch:398  d_loss:0.3632  g_loss:1.8332
# epoch:399  d_loss:0.3728  g_loss:1.8487
# epoch:400  d_loss:0.4210  g_loss:1.9484
# epoch:401  d_loss:0.2963  g_loss:2.4287
# epoch:402  d_loss:0.3158  g_loss:2.3298
# epoch:403  d_loss:0.3161  g_loss:2.1741
# epoch:404  d_loss:0.3371  g_loss:1.9100
# epoch:405  d_loss:0.3425  g_loss:1.7472
# epoch:406  d_loss:0.3372  g_loss:1.8076
# epoch:407  d_loss:0.2453  g_loss:2.1647
# epoch:408  d_loss:0.2716  g_loss:2.4039
# epoch:409  d_loss:0.3285  g_loss:2.4856
# epoch:410  d_loss:0.2793  g_loss:2.3915
# epoch:411  d_loss:0.3830  g_loss:2.0514
# epoch:412  d_loss:0.3374  g_loss:1.9258
# epoch:413  d_loss:0.4001  g_loss:1.8752
# epoch:414  d_loss:0.3251  g_loss:2.4583
# epoch:415  d_loss:0.3608  g_loss:2.0190
# epoch:416  d_loss:0.3155  g_loss:2.3945
# epoch:417  d_loss:0.3638  g_loss:2.1842
# epoch:418  d_loss:0.3682  g_loss:2.1109
# epoch:419  d_loss:0.2879  g_loss:2.8361
# epoch:420  d_loss:0.3142  g_loss:2.4773
# epoch:421  d_loss:0.3729  g_loss:2.1631
# epoch:422  d_loss:0.3682  g_loss:1.7683
# epoch:423  d_loss:0.3913  g_loss:1.6524
# epoch:424  d_loss:0.4776  g_loss:2.3441
# epoch:425  d_loss:0.4400  g_loss:3.1161
# epoch:426  d_loss:0.3523  g_loss:2.9768
# epoch:427  d_loss:0.3742  g_loss:2.5431
# epoch:428  d_loss:0.3358  g_loss:2.2764
# epoch:429  d_loss:0.5322  g_loss:1.8299
# epoch:430  d_loss:0.5521  g_loss:1.4451
# epoch:431  d_loss:0.3832  g_loss:2.0081
# epoch:432  d_loss:0.4213  g_loss:2.4681
# epoch:433  d_loss:0.4687  g_loss:2.9086
# epoch:434  d_loss:0.5142  g_loss:2.2424
# epoch:435  d_loss:0.3922  g_loss:1.7464
# epoch:436  d_loss:0.4449  g_loss:1.3909
# epoch:437  d_loss:0.4862  g_loss:1.3455
# epoch:438  d_loss:0.4438  g_loss:1.7275
# epoch:439  d_loss:0.2826  g_loss:2.3384
# epoch:440  d_loss:0.3947  g_loss:2.5403
# epoch:441  d_loss:0.3567  g_loss:2.2938
# epoch:442  d_loss:0.4184  g_loss:2.0298
# epoch:443  d_loss:0.3412  g_loss:1.9501
# epoch:444  d_loss:0.4236  g_loss:1.7298
# epoch:445  d_loss:0.3221  g_loss:2.4158
# epoch:446  d_loss:0.3704  g_loss:1.8572
# epoch:447  d_loss:0.3501  g_loss:2.1967
# epoch:448  d_loss:0.3085  g_loss:2.4980
# epoch:449  d_loss:0.3011  g_loss:2.0179
# epoch:450  d_loss:0.3111  g_loss:2.1390
# epoch:451  d_loss:0.2793  g_loss:2.5418
# epoch:452  d_loss:0.2086  g_loss:2.6356
# epoch:453  d_loss:0.2421  g_loss:2.7086
# epoch:454  d_loss:0.1423  g_loss:2.7482
# epoch:455  d_loss:0.3131  g_loss:2.6527
# epoch:456  d_loss:0.2975  g_loss:2.4616
# epoch:457  d_loss:0.2698  g_loss:2.0411
# epoch:458  d_loss:0.2529  g_loss:2.0711
# epoch:459  d_loss:0.2444  g_loss:1.9979
# epoch:460  d_loss:0.2281  g_loss:2.5956
# epoch:461  d_loss:0.2933  g_loss:2.4098
# epoch:462  d_loss:0.2950  g_loss:2.7463
# epoch:463  d_loss:0.2965  g_loss:2.6124
# epoch:464  d_loss:0.2569  g_loss:2.6397
# epoch:465  d_loss:0.2610  g_loss:2.5597
# epoch:466  d_loss:0.4071  g_loss:2.2474
# epoch:467  d_loss:0.3268  g_loss:2.6835
# epoch:468  d_loss:0.1919  g_loss:2.4801
# epoch:469  d_loss:0.2246  g_loss:2.5669
# epoch:470  d_loss:0.3436  g_loss:2.3327
# epoch:471  d_loss:0.4662  g_loss:2.4198
# epoch:472  d_loss:0.2515  g_loss:2.2890
# epoch:473  d_loss:0.2376  g_loss:2.2767
# epoch:474  d_loss:0.3457  g_loss:3.0987
# epoch:475  d_loss:0.3341  g_loss:2.2686
# epoch:476  d_loss:0.3488  g_loss:2.0978
# epoch:477  d_loss:0.3562  g_loss:2.4597
# epoch:478  d_loss:0.2428  g_loss:2.4723
# epoch:479  d_loss:0.3320  g_loss:2.1915
# epoch:480  d_loss:0.3386  g_loss:1.8599
# epoch:481  d_loss:0.4346  g_loss:2.1307
# epoch:482  d_loss:0.4734  g_loss:2.5305
# epoch:483  d_loss:0.2937  g_loss:2.8796
# epoch:484  d_loss:0.2705  g_loss:2.7858
# epoch:485  d_loss:0.3317  g_loss:2.1673
# epoch:486  d_loss:0.5406  g_loss:1.6386
# epoch:487  d_loss:0.4028  g_loss:1.9356
# epoch:488  d_loss:0.3189  g_loss:2.2633
# epoch:489  d_loss:0.4012  g_loss:2.3849
# epoch:490  d_loss:0.3871  g_loss:2.0420
# epoch:491  d_loss:0.3742  g_loss:2.3018
# epoch:492  d_loss:0.4708  g_loss:1.7826
# epoch:493  d_loss:0.2319  g_loss:2.1162
# epoch:494  d_loss:0.2725  g_loss:2.6353
# epoch:495  d_loss:0.2493  g_loss:2.5140
# epoch:496  d_loss:0.3521  g_loss:2.5800
# epoch:497  d_loss:0.2834  g_loss:2.4952
# epoch:498  d_loss:0.3777  g_loss:2.0315
# epoch:499  d_loss:0.2543  g_loss:2.0477
# epoch:500  d_loss:0.2084  g_loss:2.5418
# epoch:501  d_loss:0.2422  g_loss:2.3853
# epoch:502  d_loss:0.2200  g_loss:3.0963
# epoch:503  d_loss:0.2155  g_loss:2.7826
# epoch:504  d_loss:0.1979  g_loss:2.5575
# epoch:505  d_loss:0.1904  g_loss:2.6121
# epoch:506  d_loss:0.2255  g_loss:2.4730
# epoch:507  d_loss:0.1469  g_loss:2.6021
# epoch:508  d_loss:0.2361  g_loss:2.4464
# epoch:509  d_loss:0.2086  g_loss:2.8946
# epoch:510  d_loss:0.1775  g_loss:3.0156
# epoch:511  d_loss:0.2217  g_loss:2.4268
# epoch:512  d_loss:0.2243  g_loss:2.5245
# epoch:513  d_loss:0.1884  g_loss:2.8279
# epoch:514  d_loss:0.2274  g_loss:2.8282
# epoch:515  d_loss:0.1686  g_loss:3.4641
# epoch:516  d_loss:0.1479  g_loss:2.5436
# epoch:517  d_loss:0.1958  g_loss:2.9758
# epoch:518  d_loss:0.1733  g_loss:2.8505
# epoch:519  d_loss:0.2117  g_loss:2.5819
# epoch:520  d_loss:0.1378  g_loss:2.8833
# epoch:521  d_loss:0.2354  g_loss:2.4218
# epoch:522  d_loss:0.2709  g_loss:2.6703
# epoch:523  d_loss:0.2083  g_loss:2.9673
# epoch:524  d_loss:0.2445  g_loss:2.9140
# epoch:525  d_loss:0.2795  g_loss:2.6585
# epoch:526  d_loss:0.2316  g_loss:2.1363
# epoch:527  d_loss:0.1877  g_loss:3.2476
# epoch:528  d_loss:0.3036  g_loss:2.2263
# epoch:529  d_loss:0.3406  g_loss:2.5442
# epoch:530  d_loss:0.4313  g_loss:1.9918
# epoch:531  d_loss:0.3225  g_loss:2.5392
# epoch:532  d_loss:0.3221  g_loss:3.0452
# epoch:533  d_loss:0.3417  g_loss:3.2979
# epoch:534  d_loss:0.2974  g_loss:2.3701
# epoch:535  d_loss:0.3758  g_loss:1.7470
# epoch:536  d_loss:0.2818  g_loss:1.6691
# epoch:537  d_loss:0.2323  g_loss:3.0248
# epoch:538  d_loss:0.1767  g_loss:3.3488
# epoch:539  d_loss:0.4292  g_loss:3.0106
# epoch:540  d_loss:0.3266  g_loss:2.2164
# epoch:541  d_loss:0.1787  g_loss:2.0470
# epoch:542  d_loss:0.1558  g_loss:2.6210
# epoch:543  d_loss:0.1257  g_loss:3.1086
# epoch:544  d_loss:0.1744  g_loss:3.1556
# epoch:545  d_loss:0.2008  g_loss:3.2254
# epoch:546  d_loss:0.2040  g_loss:2.6566
# epoch:547  d_loss:0.2192  g_loss:2.8167
# epoch:548  d_loss:0.1045  g_loss:2.9076
# epoch:549  d_loss:0.1242  g_loss:3.7131
# epoch:550  d_loss:0.1652  g_loss:3.1090
# epoch:551  d_loss:0.1791  g_loss:2.6303
# epoch:552  d_loss:0.2283  g_loss:3.2522
# epoch:553  d_loss:0.2522  g_loss:3.1048
# epoch:554  d_loss:0.2041  g_loss:3.3779
# epoch:555  d_loss:0.1525  g_loss:3.2278
# epoch:556  d_loss:0.2296  g_loss:2.6216
# epoch:557  d_loss:0.1302  g_loss:2.9207
# epoch:558  d_loss:0.1747  g_loss:2.8175
# epoch:559  d_loss:0.2011  g_loss:2.4869
# epoch:560  d_loss:0.2957  g_loss:1.9117
# epoch:561  d_loss:0.2150  g_loss:2.3908
# epoch:562  d_loss:0.1537  g_loss:2.6689
# epoch:563  d_loss:0.1668  g_loss:3.0727
# epoch:564  d_loss:0.1872  g_loss:2.5849
# epoch:565  d_loss:0.2311  g_loss:2.2047
# epoch:566  d_loss:0.2761  g_loss:2.8979
# epoch:567  d_loss:0.3172  g_loss:2.3977
# epoch:568  d_loss:0.3326  g_loss:2.7662
# epoch:569  d_loss:0.1979  g_loss:3.0317
# epoch:570  d_loss:0.2497  g_loss:3.1117
# epoch:571  d_loss:0.2648  g_loss:2.9470
# epoch:572  d_loss:0.2142  g_loss:2.8714
# epoch:573  d_loss:0.4053  g_loss:2.0994
# epoch:574  d_loss:0.1467  g_loss:2.6403
# epoch:575  d_loss:0.2160  g_loss:2.7457
# epoch:576  d_loss:0.2254  g_loss:3.4642
# epoch:577  d_loss:0.3416  g_loss:3.4378
# epoch:578  d_loss:0.2747  g_loss:2.4247
# epoch:579  d_loss:0.2577  g_loss:2.2791
# epoch:580  d_loss:0.1982  g_loss:2.3531
# epoch:581  d_loss:0.1162  g_loss:3.5460
# epoch:582  d_loss:0.2555  g_loss:3.3380
# epoch:583  d_loss:0.1748  g_loss:2.3182
# epoch:584  d_loss:0.2970  g_loss:2.1441
# epoch:585  d_loss:0.1870  g_loss:2.4327
# epoch:586  d_loss:0.1461  g_loss:2.7391
# epoch:587  d_loss:0.1769  g_loss:3.7231
# epoch:588  d_loss:0.1127  g_loss:4.5971
# epoch:589  d_loss:0.2623  g_loss:3.0891
# epoch:590  d_loss:0.2435  g_loss:2.5272
# epoch:591  d_loss:0.1879  g_loss:2.6443
# epoch:592  d_loss:0.1131  g_loss:3.2054
# epoch:593  d_loss:0.1648  g_loss:3.9234
# epoch:594  d_loss:0.1207  g_loss:3.9841
# epoch:595  d_loss:0.3190  g_loss:2.3767
# epoch:596  d_loss:0.2077  g_loss:1.8608
# epoch:597  d_loss:0.2170  g_loss:1.6611
# epoch:598  d_loss:0.2731  g_loss:2.0897
# epoch:599  d_loss:0.2113  g_loss:3.6799
# epoch:600  d_loss:0.3450  g_loss:4.2089
# epoch:601  d_loss:0.3007  g_loss:3.2590
# epoch:602  d_loss:0.3705  g_loss:2.1852
# epoch:603  d_loss:0.2644  g_loss:1.8380
# epoch:604  d_loss:0.2323  g_loss:1.7618
# epoch:605  d_loss:0.1231  g_loss:3.3225
# epoch:606  d_loss:0.1825  g_loss:3.5157
# epoch:607  d_loss:0.1547  g_loss:4.1795
# epoch:608  d_loss:0.2657  g_loss:3.5089
# epoch:609  d_loss:0.2669  g_loss:2.3934
# epoch:610  d_loss:0.1847  g_loss:2.1030
# epoch:611  d_loss:0.2660  g_loss:2.1613
# epoch:612  d_loss:0.1856  g_loss:2.3593
# epoch:613  d_loss:0.4882  g_loss:3.0468
# epoch:614  d_loss:0.2321  g_loss:2.8058
# epoch:615  d_loss:0.4453  g_loss:1.7991
# epoch:616  d_loss:0.2885  g_loss:1.7092
# epoch:617  d_loss:0.3190  g_loss:2.3132
# epoch:618  d_loss:0.3381  g_loss:3.1071
# epoch:619  d_loss:0.3432  g_loss:2.9457
# epoch:620  d_loss:0.3656  g_loss:2.4085
# epoch:621  d_loss:0.4663  g_loss:1.3046
# epoch:622  d_loss:0.4557  g_loss:1.6204
# epoch:623  d_loss:0.2100  g_loss:3.2758
# epoch:624  d_loss:0.4252  g_loss:3.1433
# epoch:625  d_loss:0.5429  g_loss:2.0272
# epoch:626  d_loss:0.4518  g_loss:1.2980
# epoch:627  d_loss:0.2382  g_loss:1.8192
# epoch:628  d_loss:0.1561  g_loss:3.0249
# epoch:629  d_loss:0.1541  g_loss:2.9349
# epoch:630  d_loss:0.2392  g_loss:2.5758
# epoch:631  d_loss:0.1527  g_loss:2.4343
# epoch:632  d_loss:0.2311  g_loss:1.7030
# epoch:633  d_loss:0.2891  g_loss:1.6188
# epoch:634  d_loss:0.2473  g_loss:1.9555
# epoch:635  d_loss:0.1712  g_loss:2.3619
# epoch:636  d_loss:0.2605  g_loss:2.3768
# epoch:637  d_loss:0.3989  g_loss:1.8747
# epoch:638  d_loss:0.2360  g_loss:2.4113
# epoch:639  d_loss:0.4015  g_loss:1.7505
# epoch:640  d_loss:0.2952  g_loss:1.7200
# epoch:641  d_loss:0.4368  g_loss:1.4825
# epoch:642  d_loss:0.5961  g_loss:1.2699
# epoch:643  d_loss:0.5858  g_loss:1.6246
# epoch:644  d_loss:0.5036  g_loss:1.8904
# epoch:645  d_loss:0.7719  g_loss:1.1451
# epoch:646  d_loss:0.6661  g_loss:1.1583
# epoch:647  d_loss:0.5385  g_loss:1.3141
# epoch:648  d_loss:0.6493  g_loss:1.0754
# epoch:649  d_loss:0.4339  g_loss:1.4611
# epoch:650  d_loss:0.8519  g_loss:1.6241
# epoch:651  d_loss:0.9638  g_loss:0.9808
# epoch:652  d_loss:0.6586  g_loss:1.5169
# epoch:653  d_loss:0.5719  g_loss:2.2033
# epoch:654  d_loss:0.5347  g_loss:2.5471
# epoch:655  d_loss:0.3716  g_loss:2.9377
# epoch:656  d_loss:0.6019  g_loss:1.8259
# epoch:657  d_loss:0.9986  g_loss:0.8643
# epoch:658  d_loss:1.0528  g_loss:1.0287
# epoch:659  d_loss:0.5372  g_loss:1.5190
# epoch:660  d_loss:0.4391  g_loss:2.1816
# epoch:661  d_loss:0.7846  g_loss:2.4278
# epoch:662  d_loss:0.5730  g_loss:1.7513
# epoch:663  d_loss:0.8027  g_loss:0.4881
# epoch:664  d_loss:0.9224  g_loss:0.3451
# epoch:665  d_loss:1.0123  g_loss:0.6580
# epoch:666  d_loss:0.3208  g_loss:2.2365
# epoch:667  d_loss:0.7217  g_loss:2.4655
# epoch:668  d_loss:0.8934  g_loss:1.6782
# epoch:669  d_loss:0.7357  g_loss:1.0576
# epoch:670  d_loss:0.7263  g_loss:0.7434
# epoch:671  d_loss:0.7387  g_loss:0.7091
# epoch:672  d_loss:0.7645  g_loss:0.9361
# epoch:673  d_loss:0.7522  g_loss:1.5007
# epoch:674  d_loss:1.0136  g_loss:1.4228
# epoch:675  d_loss:0.8289  g_loss:1.3862
# epoch:676  d_loss:0.9755  g_loss:1.2072
# epoch:677  d_loss:0.8290  g_loss:1.5460
# epoch:678  d_loss:0.4057  g_loss:1.7574
# epoch:679  d_loss:0.5005  g_loss:2.0138
# epoch:680  d_loss:0.3589  g_loss:1.9927
# epoch:681  d_loss:0.3730  g_loss:2.6569
# epoch:682  d_loss:0.2145  g_loss:2.1907
# epoch:683  d_loss:0.2821  g_loss:2.1851
# epoch:684  d_loss:0.3484  g_loss:1.9233
# epoch:685  d_loss:0.3967  g_loss:2.0128
# epoch:686  d_loss:0.4180  g_loss:1.6681
# epoch:687  d_loss:0.2890  g_loss:1.9730
# epoch:688  d_loss:0.3411  g_loss:2.1235
# epoch:689  d_loss:0.4114  g_loss:2.0213
# epoch:690  d_loss:0.5747  g_loss:1.9757
# epoch:691  d_loss:0.6214  g_loss:1.7264
# epoch:692  d_loss:0.5015  g_loss:1.4502
# epoch:693  d_loss:0.6215  g_loss:1.0888
# epoch:694  d_loss:0.7272  g_loss:1.2074
# epoch:695  d_loss:0.6238  g_loss:1.5133
# epoch:696  d_loss:0.8583  g_loss:1.1228
# epoch:697  d_loss:0.8004  g_loss:1.3100
# epoch:698  d_loss:0.9691  g_loss:1.3506
# epoch:699  d_loss:1.0825  g_loss:0.8637
# epoch:700  d_loss:0.9373  g_loss:0.9867
# epoch:701  d_loss:0.8699  g_loss:1.0321
# epoch:702  d_loss:0.7538  g_loss:1.1232
# epoch:703  d_loss:0.6798  g_loss:1.1432
# epoch:704  d_loss:0.4669  g_loss:1.3563
# epoch:705  d_loss:0.5952  g_loss:1.6907
# epoch:706  d_loss:0.4420  g_loss:1.7351
# epoch:707  d_loss:0.3352  g_loss:1.5575
# epoch:708  d_loss:0.3575  g_loss:1.7060
# epoch:709  d_loss:0.2792  g_loss:1.8180
# epoch:710  d_loss:0.2772  g_loss:2.1959
# epoch:711  d_loss:0.2030  g_loss:2.3145
# epoch:712  d_loss:0.2226  g_loss:2.0387
# epoch:713  d_loss:0.2589  g_loss:2.2041
# epoch:714  d_loss:0.2001  g_loss:2.3069
# epoch:715  d_loss:0.3034  g_loss:2.7085
# epoch:716  d_loss:0.1020  g_loss:3.2523
# epoch:717  d_loss:0.1148  g_loss:3.1899
# epoch:718  d_loss:0.2138  g_loss:3.5173
# epoch:719  d_loss:0.2178  g_loss:3.4204
# epoch:720  d_loss:0.3173  g_loss:2.8869
# epoch:721  d_loss:0.2238  g_loss:2.6799
# epoch:722  d_loss:0.3691  g_loss:2.4977
# epoch:723  d_loss:0.5165  g_loss:2.8598
# epoch:724  d_loss:0.3607  g_loss:3.5418
# epoch:725  d_loss:0.5597  g_loss:3.8768
# epoch:726  d_loss:0.6225  g_loss:2.8754
# epoch:727  d_loss:0.6246  g_loss:1.7220
# epoch:728  d_loss:0.5444  g_loss:1.1984
# epoch:729  d_loss:0.6592  g_loss:1.1123
# epoch:730  d_loss:0.4991  g_loss:1.4795
# epoch:731  d_loss:0.5707  g_loss:1.8552
# epoch:732  d_loss:0.5147  g_loss:1.9576
# epoch:733  d_loss:0.7073  g_loss:1.7502
# epoch:734  d_loss:0.5467  g_loss:1.8279
# epoch:735  d_loss:0.4836  g_loss:1.5502
# epoch:736  d_loss:0.4213  g_loss:1.4366
# epoch:737  d_loss:0.3289  g_loss:1.9375
# epoch:738  d_loss:0.3904  g_loss:1.6305
# epoch:739  d_loss:0.5199  g_loss:1.7991
# epoch:740  d_loss:0.4981  g_loss:1.8664
# epoch:741  d_loss:0.4499  g_loss:1.7595
# epoch:742  d_loss:0.4613  g_loss:2.1466
# epoch:743  d_loss:0.2672  g_loss:2.2935
# epoch:744  d_loss:0.3002  g_loss:2.3134
# epoch:745  d_loss:0.2359  g_loss:2.5699
# epoch:746  d_loss:0.3883  g_loss:2.5408
# epoch:747  d_loss:0.2146  g_loss:2.2674
# epoch:748  d_loss:0.1950  g_loss:2.6694
# epoch:749  d_loss:0.3264  g_loss:2.4027
# epoch:750  d_loss:0.2836  g_loss:2.5175
# epoch:751  d_loss:0.2937  g_loss:2.3559
# epoch:752  d_loss:0.1757  g_loss:2.7099
# epoch:753  d_loss:0.2075  g_loss:3.0588
# epoch:754  d_loss:0.2221  g_loss:3.0492
# epoch:755  d_loss:0.2020  g_loss:2.9459
# epoch:756  d_loss:0.4219  g_loss:2.6243
# epoch:757  d_loss:0.5671  g_loss:2.4279
# epoch:758  d_loss:0.3922  g_loss:2.1266
# epoch:759  d_loss:0.3481  g_loss:1.9869
# epoch:760  d_loss:0.3209  g_loss:2.7793
# epoch:761  d_loss:0.3588  g_loss:2.7146
# epoch:762  d_loss:0.4350  g_loss:2.1185
# epoch:763  d_loss:0.6136  g_loss:1.4877
# epoch:764  d_loss:0.6682  g_loss:1.4195
# epoch:765  d_loss:0.4621  g_loss:1.8130
# epoch:766  d_loss:0.5466  g_loss:1.6907
# epoch:767  d_loss:0.4032  g_loss:1.9904
# epoch:768  d_loss:0.4441  g_loss:1.9156
# epoch:769  d_loss:0.4907  g_loss:1.8872
# epoch:770  d_loss:0.6206  g_loss:1.8975
# epoch:771  d_loss:0.3149  g_loss:1.5596
# epoch:772  d_loss:0.3486  g_loss:1.8299
# epoch:773  d_loss:0.4198  g_loss:1.7417
# epoch:774  d_loss:0.3789  g_loss:1.8071
# epoch:775  d_loss:0.4147  g_loss:2.1023
# epoch:776  d_loss:0.3453  g_loss:2.0009
# epoch:777  d_loss:0.3357  g_loss:1.8469
# epoch:778  d_loss:0.3007  g_loss:2.1712
# epoch:779  d_loss:0.3191  g_loss:2.1241
# epoch:780  d_loss:0.5068  g_loss:1.6848
# epoch:781  d_loss:0.4136  g_loss:1.9125
# epoch:782  d_loss:0.2366  g_loss:2.5740
# epoch:783  d_loss:0.3032  g_loss:2.5034
# epoch:784  d_loss:0.3441  g_loss:2.0846
# epoch:785  d_loss:0.2792  g_loss:2.3204
# epoch:786  d_loss:0.2603  g_loss:2.1907
# epoch:787  d_loss:0.2642  g_loss:2.5714
# epoch:788  d_loss:0.2251  g_loss:2.3901
# epoch:789  d_loss:0.2586  g_loss:2.2151
# epoch:790  d_loss:0.3823  g_loss:2.3443
# epoch:791  d_loss:0.2873  g_loss:2.6291
# epoch:792  d_loss:0.2787  g_loss:2.9028
# epoch:793  d_loss:0.3508  g_loss:3.1316
# epoch:794  d_loss:0.3246  g_loss:2.6085
# epoch:795  d_loss:0.3395  g_loss:2.1262
# epoch:796  d_loss:0.4787  g_loss:1.5440
# epoch:797  d_loss:0.3906  g_loss:1.8095
# epoch:798  d_loss:0.4658  g_loss:2.0762
# epoch:799  d_loss:0.5032  g_loss:1.8133
# epoch:800  d_loss:0.4146  g_loss:2.1287
# epoch:801  d_loss:0.4577  g_loss:1.6600
# epoch:802  d_loss:0.6005  g_loss:1.5218
# epoch:803  d_loss:0.6080  g_loss:1.3827
# epoch:804  d_loss:0.4025  g_loss:2.0706
# epoch:805  d_loss:0.5720  g_loss:1.3884
# epoch:806  d_loss:0.5093  g_loss:1.4343
# epoch:807  d_loss:0.4506  g_loss:1.3828
# epoch:808  d_loss:0.5474  g_loss:1.3041
# epoch:809  d_loss:0.4030  g_loss:1.4221
# epoch:810  d_loss:0.5506  g_loss:1.4262
# epoch:811  d_loss:0.4227  g_loss:1.4504
# epoch:812  d_loss:0.4173  g_loss:1.5535
# epoch:813  d_loss:0.3572  g_loss:1.7597
# epoch:814  d_loss:0.4113  g_loss:1.6622
# epoch:815  d_loss:0.4654  g_loss:1.6414
# epoch:816  d_loss:0.4273  g_loss:1.3425
# epoch:817  d_loss:0.4449  g_loss:1.4989
# epoch:818  d_loss:0.4646  g_loss:1.1035
# epoch:819  d_loss:0.4488  g_loss:1.5154
# epoch:820  d_loss:0.3819  g_loss:1.5868
# epoch:821  d_loss:0.3902  g_loss:1.6624
# epoch:822  d_loss:0.3856  g_loss:1.7712
# epoch:823  d_loss:0.4479  g_loss:1.9660
# epoch:824  d_loss:0.4366  g_loss:1.9446
# epoch:825  d_loss:0.3696  g_loss:1.8470
# epoch:826  d_loss:0.3845  g_loss:1.6423
# epoch:827  d_loss:0.3603  g_loss:1.3713
# epoch:828  d_loss:0.3984  g_loss:1.7441
# epoch:829  d_loss:0.3628  g_loss:1.8320
# epoch:830  d_loss:0.4827  g_loss:2.0060
# epoch:831  d_loss:0.4598  g_loss:1.7680
# epoch:832  d_loss:0.4407  g_loss:1.4823
# epoch:833  d_loss:0.4658  g_loss:1.4980
# epoch:834  d_loss:0.3671  g_loss:1.8454
# epoch:835  d_loss:0.4733  g_loss:2.0035
# epoch:836  d_loss:0.3904  g_loss:2.0293
# epoch:837  d_loss:0.3392  g_loss:2.0337
# epoch:838  d_loss:0.5871  g_loss:1.4046
# epoch:839  d_loss:0.4951  g_loss:1.6396
# epoch:840  d_loss:0.4770  g_loss:1.5460
# epoch:841  d_loss:0.4629  g_loss:1.7200
# epoch:842  d_loss:0.4528  g_loss:1.9913
# epoch:843  d_loss:0.5921  g_loss:1.6259
# epoch:844  d_loss:0.5473  g_loss:1.9083
# epoch:845  d_loss:0.4896  g_loss:1.9329
# epoch:846  d_loss:0.3292  g_loss:1.8185
# epoch:847  d_loss:0.5746  g_loss:2.0208
# epoch:848  d_loss:0.5421  g_loss:1.7066
# epoch:849  d_loss:0.3413  g_loss:1.7464
# epoch:850  d_loss:0.4374  g_loss:2.1025
# epoch:851  d_loss:0.3748  g_loss:2.1427
# epoch:852  d_loss:0.4832  g_loss:1.6311
# epoch:853  d_loss:0.4159  g_loss:1.7146
# epoch:854  d_loss:0.3728  g_loss:1.4243
# epoch:855  d_loss:0.4797  g_loss:1.4891
# epoch:856  d_loss:0.4233  g_loss:1.8470
# epoch:857  d_loss:0.4784  g_loss:1.7297
# epoch:858  d_loss:0.4255  g_loss:2.1863
# epoch:859  d_loss:0.3018  g_loss:2.4490
# epoch:860  d_loss:0.5176  g_loss:2.1892
# epoch:861  d_loss:0.3992  g_loss:2.1489
# epoch:862  d_loss:0.3966  g_loss:1.9008
# epoch:863  d_loss:0.3267  g_loss:1.8548
# epoch:864  d_loss:0.3664  g_loss:2.1487
# epoch:865  d_loss:0.3388  g_loss:2.4072
# epoch:866  d_loss:0.4023  g_loss:2.4653
# epoch:867  d_loss:0.3740  g_loss:1.9498
# epoch:868  d_loss:0.6244  g_loss:1.9972
# epoch:869  d_loss:0.5342  g_loss:2.1522
# epoch:870  d_loss:0.4734  g_loss:2.3285
# epoch:871  d_loss:0.4552  g_loss:2.5017
# epoch:872  d_loss:0.2809  g_loss:2.8179
# epoch:873  d_loss:0.4290  g_loss:2.7654
# epoch:874  d_loss:0.2278  g_loss:2.6221
# epoch:875  d_loss:0.3229  g_loss:2.9444
# epoch:876  d_loss:0.1640  g_loss:3.1838
# epoch:877  d_loss:0.1528  g_loss:3.2003
# epoch:878  d_loss:0.1214  g_loss:3.9552
# epoch:879  d_loss:0.1279  g_loss:3.7334
# epoch:880  d_loss:0.2239  g_loss:3.1103
# epoch:881  d_loss:0.3404  g_loss:2.8191
# epoch:882  d_loss:0.2429  g_loss:2.1477
# epoch:883  d_loss:0.4643  g_loss:2.1087
# epoch:884  d_loss:0.4697  g_loss:2.0113
# epoch:885  d_loss:0.4259  g_loss:1.9125
# epoch:886  d_loss:0.4841  g_loss:2.2351
# epoch:887  d_loss:0.4636  g_loss:2.0455
# epoch:888  d_loss:0.4975  g_loss:1.7684
# epoch:889  d_loss:0.4668  g_loss:1.8450
# epoch:890  d_loss:0.3341  g_loss:2.0681
# epoch:891  d_loss:0.3633  g_loss:2.0718
# epoch:892  d_loss:0.4970  g_loss:1.7962
# epoch:893  d_loss:0.4149  g_loss:1.9753
# epoch:894  d_loss:0.3746  g_loss:1.6022
# epoch:895  d_loss:0.3857  g_loss:1.7171
# epoch:896  d_loss:0.5548  g_loss:1.4016
# epoch:897  d_loss:0.4220  g_loss:1.7077
# epoch:898  d_loss:0.3263  g_loss:2.1682
# epoch:899  d_loss:0.4359  g_loss:1.7988
# epoch:900  d_loss:0.4417  g_loss:2.0641
# epoch:901  d_loss:0.3984  g_loss:1.9811
# epoch:902  d_loss:0.4078  g_loss:1.5892
# epoch:903  d_loss:0.3391  g_loss:1.8123
# epoch:904  d_loss:0.3171  g_loss:1.9462
# epoch:905  d_loss:0.3489  g_loss:2.4544
# epoch:906  d_loss:0.3355  g_loss:2.1069
# epoch:907  d_loss:0.3532  g_loss:2.5761
# epoch:908  d_loss:0.4821  g_loss:2.1168
# epoch:909  d_loss:0.3757  g_loss:2.4224
# epoch:910  d_loss:0.3813  g_loss:2.3709
# epoch:911  d_loss:0.3555  g_loss:2.1659
# epoch:912  d_loss:0.2983  g_loss:2.2014
# epoch:913  d_loss:0.5066  g_loss:2.2548
# epoch:914  d_loss:0.4884  g_loss:2.3032
# epoch:915  d_loss:0.4712  g_loss:1.8390
# epoch:916  d_loss:0.4508  g_loss:1.6331
# epoch:917  d_loss:0.4057  g_loss:1.7397
# epoch:918  d_loss:0.5037  g_loss:1.2934
# epoch:919  d_loss:0.6343  g_loss:1.8010
# epoch:920  d_loss:0.3323  g_loss:2.1834
# epoch:921  d_loss:0.3474  g_loss:2.5042
# epoch:922  d_loss:0.3600  g_loss:2.5779
# epoch:923  d_loss:0.5532  g_loss:1.8681
# epoch:924  d_loss:0.3847  g_loss:1.6367
# epoch:925  d_loss:0.4561  g_loss:1.6677
# epoch:926  d_loss:0.3674  g_loss:1.6779
# epoch:927  d_loss:0.4695  g_loss:1.7537
# epoch:928  d_loss:0.3891  g_loss:2.0686
# epoch:929  d_loss:0.3088  g_loss:2.7799
# epoch:930  d_loss:0.3768  g_loss:2.4820
# epoch:931  d_loss:0.4122  g_loss:2.0822
# epoch:932  d_loss:0.3969  g_loss:2.1885
# epoch:933  d_loss:0.4162  g_loss:2.2308
# epoch:934  d_loss:0.4313  g_loss:2.1643
# epoch:935  d_loss:0.4265  g_loss:2.0435
# epoch:936  d_loss:0.3712  g_loss:1.9866
# epoch:937  d_loss:0.5364  g_loss:1.8677
# epoch:938  d_loss:0.3831  g_loss:1.5235
# epoch:939  d_loss:0.3469  g_loss:1.7683
# epoch:940  d_loss:0.3608  g_loss:1.8905
# epoch:941  d_loss:0.3441  g_loss:2.2977
# epoch:942  d_loss:0.3554  g_loss:2.6812
# epoch:943  d_loss:0.3653  g_loss:2.6501
# epoch:944  d_loss:0.3140  g_loss:2.2279
# epoch:945  d_loss:0.2557  g_loss:2.2441
# epoch:946  d_loss:0.3573  g_loss:1.9745
# epoch:947  d_loss:0.2653  g_loss:2.1034
# epoch:948  d_loss:0.3051  g_loss:2.5030
# epoch:949  d_loss:0.3512  g_loss:2.3106
# epoch:950  d_loss:0.3918  g_loss:2.2396
# epoch:951  d_loss:0.2847  g_loss:2.0528
# epoch:952  d_loss:0.3117  g_loss:2.4879
# epoch:953  d_loss:0.3206  g_loss:2.2501
# epoch:954  d_loss:0.3285  g_loss:2.1156
# epoch:955  d_loss:0.4610  g_loss:2.3250
# epoch:956  d_loss:0.3154  g_loss:2.4385
# epoch:957  d_loss:0.3133  g_loss:2.3541
# epoch:958  d_loss:0.3805  g_loss:2.0411
# epoch:959  d_loss:0.4252  g_loss:2.1128
# epoch:960  d_loss:0.3207  g_loss:2.1950
# epoch:961  d_loss:0.3468  g_loss:1.8095
# epoch:962  d_loss:0.3801  g_loss:1.7651
# epoch:963  d_loss:0.2278  g_loss:2.5826
# epoch:964  d_loss:0.2772  g_loss:2.1516
# epoch:965  d_loss:0.4542  g_loss:2.2460
# epoch:966  d_loss:0.4590  g_loss:2.0185
# epoch:967  d_loss:0.4074  g_loss:1.7935
# epoch:968  d_loss:0.4648  g_loss:1.9509
# epoch:969  d_loss:0.3786  g_loss:1.7193
# epoch:970  d_loss:0.4777  g_loss:1.6641
# epoch:971  d_loss:0.6115  g_loss:1.9118
# epoch:972  d_loss:0.5325  g_loss:1.7976
# epoch:973  d_loss:0.4330  g_loss:1.7443
# epoch:974  d_loss:0.5413  g_loss:1.8200
# epoch:975  d_loss:0.3954  g_loss:1.9188
# epoch:976  d_loss:0.3380  g_loss:1.7630
# epoch:977  d_loss:0.4909  g_loss:1.3960
# epoch:978  d_loss:0.5810  g_loss:1.3231
# epoch:979  d_loss:0.5148  g_loss:1.5377
# epoch:980  d_loss:0.4705  g_loss:2.1226
# epoch:981  d_loss:0.3938  g_loss:2.0981
# epoch:982  d_loss:0.5760  g_loss:2.0669
# epoch:983  d_loss:0.4858  g_loss:1.8745
# epoch:984  d_loss:0.4700  g_loss:1.7584
# epoch:985  d_loss:0.5490  g_loss:1.4961
# epoch:986  d_loss:0.3187  g_loss:1.6163
# epoch:987  d_loss:0.3597  g_loss:1.4284
# epoch:988  d_loss:0.3221  g_loss:2.1079
# epoch:989  d_loss:0.2323  g_loss:2.3261
# epoch:990  d_loss:0.3704  g_loss:2.3497
# epoch:991  d_loss:0.3391  g_loss:2.5055
# epoch:992  d_loss:0.3641  g_loss:3.0264
# epoch:993  d_loss:0.3758  g_loss:2.0728
# epoch:994  d_loss:0.4060  g_loss:1.8150
# epoch:995  d_loss:0.4148  g_loss:1.7257
# epoch:996  d_loss:0.4004  g_loss:1.5600
# epoch:997  d_loss:0.4742  g_loss:1.3506
# epoch:998  d_loss:0.3853  g_loss:1.7497
# epoch:999  d_loss:0.3941  g_loss:2.1293
# epoch:1000  d_loss:0.2083  g_loss:2.5443
# epoch:1001  d_loss:0.3909  g_loss:2.5081
# epoch:1002  d_loss:0.4254  g_loss:2.1756
# epoch:1003  d_loss:0.4486  g_loss:2.2255
# epoch:1004  d_loss:0.4017  g_loss:1.4892
# epoch:1005  d_loss:0.5304  g_loss:1.6844
# epoch:1006  d_loss:0.2605  g_loss:1.9607
# epoch:1007  d_loss:0.3128  g_loss:1.9491
# epoch:1008  d_loss:0.3277  g_loss:1.9215
# epoch:1009  d_loss:0.3222  g_loss:2.3160
# epoch:1010  d_loss:0.3391  g_loss:2.0149
# epoch:1011  d_loss:0.3992  g_loss:1.7950
# epoch:1012  d_loss:0.4154  g_loss:1.8063
# epoch:1013  d_loss:0.3934  g_loss:1.4683
# epoch:1014  d_loss:0.4287  g_loss:1.8233
# epoch:1015  d_loss:0.2466  g_loss:2.1170
# epoch:1016  d_loss:0.4232  g_loss:2.1439
# epoch:1017  d_loss:0.2328  g_loss:2.5213
# epoch:1018  d_loss:0.3753  g_loss:2.2849
# epoch:1019  d_loss:0.2870  g_loss:2.1850
# epoch:1020  d_loss:0.3458  g_loss:2.1162
# epoch:1021  d_loss:0.2289  g_loss:1.9574
# epoch:1022  d_loss:0.2941  g_loss:2.2495
# epoch:1023  d_loss:0.3014  g_loss:2.3516
# epoch:1024  d_loss:0.2648  g_loss:2.7020
# epoch:1025  d_loss:0.3404  g_loss:2.1437
# epoch:1026  d_loss:0.2245  g_loss:1.4904
# epoch:1027  d_loss:0.2274  g_loss:2.0644
# epoch:1028  d_loss:0.3286  g_loss:2.1298
# epoch:1029  d_loss:0.2150  g_loss:3.0380
# epoch:1030  d_loss:0.1983  g_loss:2.6736
# epoch:1031  d_loss:0.2641  g_loss:2.6856
# epoch:1032  d_loss:0.3040  g_loss:2.5010
# epoch:1033  d_loss:0.3128  g_loss:1.6977
# epoch:1034  d_loss:0.3699  g_loss:1.8926
# epoch:1035  d_loss:0.1975  g_loss:2.0261
# epoch:1036  d_loss:0.4426  g_loss:1.9448
# epoch:1037  d_loss:0.3836  g_loss:1.6855
# epoch:1038  d_loss:0.4041  g_loss:1.8735
# epoch:1039  d_loss:0.4011  g_loss:2.0378
# epoch:1040  d_loss:0.4812  g_loss:1.5772
# epoch:1041  d_loss:0.5235  g_loss:1.6844
# epoch:1042  d_loss:0.5416  g_loss:1.5017
# epoch:1043  d_loss:0.4924  g_loss:1.3471
# epoch:1044  d_loss:0.5175  g_loss:1.4221
# epoch:1045  d_loss:0.5713  g_loss:1.6190
# epoch:1046  d_loss:0.6313  g_loss:1.3628
# epoch:1047  d_loss:0.6630  g_loss:1.7492
# epoch:1048  d_loss:0.5204  g_loss:1.8738
# epoch:1049  d_loss:0.6075  g_loss:1.7593
# epoch:1050  d_loss:0.6122  g_loss:1.6740
# epoch:1051  d_loss:0.7207  g_loss:1.3181
# epoch:1052  d_loss:0.6594  g_loss:1.2558
# epoch:1053  d_loss:0.5597  g_loss:1.7345
# epoch:1054  d_loss:0.3892  g_loss:1.6343
# epoch:1055  d_loss:0.5976  g_loss:1.8876
# epoch:1056  d_loss:0.4603  g_loss:1.7392
# epoch:1057  d_loss:0.3735  g_loss:1.9238
# epoch:1058  d_loss:0.4136  g_loss:1.8532
# epoch:1059  d_loss:0.3712  g_loss:2.3466
# epoch:1060  d_loss:0.3788  g_loss:1.9851
# epoch:1061  d_loss:0.3132  g_loss:2.0300
# epoch:1062  d_loss:0.3435  g_loss:1.8549
# epoch:1063  d_loss:0.4234  g_loss:2.0281
# epoch:1064  d_loss:0.3176  g_loss:1.8531
# epoch:1065  d_loss:0.2880  g_loss:2.1164
# epoch:1066  d_loss:0.3375  g_loss:2.1266
# epoch:1067  d_loss:0.3635  g_loss:2.5046
# epoch:1068  d_loss:0.2622  g_loss:2.3346
# epoch:1069  d_loss:0.3273  g_loss:2.1670
# epoch:1070  d_loss:0.3833  g_loss:2.0302
# epoch:1071  d_loss:0.3701  g_loss:2.4410
# epoch:1072  d_loss:0.3811  g_loss:2.2214
# epoch:1073  d_loss:0.2640  g_loss:2.4715
# epoch:1074  d_loss:0.2757  g_loss:2.1731
# epoch:1075  d_loss:0.4291  g_loss:1.8761
# epoch:1076  d_loss:0.3479  g_loss:1.9149
# epoch:1077  d_loss:0.3490  g_loss:1.5799
# epoch:1078  d_loss:0.3496  g_loss:2.2824
# epoch:1079  d_loss:0.3631  g_loss:2.3966
# epoch:1080  d_loss:0.5303  g_loss:2.6522
# epoch:1081  d_loss:0.4250  g_loss:2.1603
# epoch:1082  d_loss:0.4971  g_loss:1.7588
# epoch:1083  d_loss:0.4111  g_loss:1.5404
# epoch:1084  d_loss:0.4568  g_loss:1.7593
# epoch:1085  d_loss:0.5301  g_loss:1.5768
# epoch:1086  d_loss:0.5300  g_loss:1.8869
# epoch:1087  d_loss:0.5064  g_loss:2.2687
# epoch:1088  d_loss:0.4327  g_loss:2.2739
# epoch:1089  d_loss:0.4652  g_loss:1.5753
# epoch:1090  d_loss:0.4438  g_loss:1.7219
# epoch:1091  d_loss:0.5151  g_loss:1.8364
# epoch:1092  d_loss:0.4217  g_loss:1.8438
# epoch:1093  d_loss:0.2968  g_loss:2.5717
# epoch:1094  d_loss:0.4416  g_loss:2.3847
# epoch:1095  d_loss:0.5612  g_loss:1.9282
# epoch:1096  d_loss:0.4140  g_loss:1.7073
# epoch:1097  d_loss:0.4049  g_loss:1.7885
# epoch:1098  d_loss:0.3529  g_loss:1.8232
# epoch:1099  d_loss:0.2994  g_loss:2.8565
# epoch:1100  d_loss:0.3302  g_loss:2.5161
# epoch:1101  d_loss:0.3297  g_loss:2.5813
# epoch:1102  d_loss:0.2600  g_loss:1.8892
# epoch:1103  d_loss:0.3089  g_loss:2.1638
# epoch:1104  d_loss:0.2694  g_loss:2.0760
# epoch:1105  d_loss:0.2871  g_loss:2.5959
# epoch:1106  d_loss:0.1915  g_loss:2.6650
# epoch:1107  d_loss:0.3697  g_loss:2.8784
# epoch:1108  d_loss:0.3983  g_loss:2.2955
# epoch:1109  d_loss:0.2508  g_loss:2.3423
# epoch:1110  d_loss:0.4442  g_loss:2.1591
# epoch:1111  d_loss:0.3990  g_loss:2.1121
# epoch:1112  d_loss:0.3759  g_loss:2.1512
# epoch:1113  d_loss:0.4506  g_loss:2.4525
# epoch:1114  d_loss:0.2943  g_loss:2.8571
# epoch:1115  d_loss:0.3946  g_loss:3.0667
# epoch:1116  d_loss:0.4875  g_loss:2.1851
# epoch:1117  d_loss:0.4542  g_loss:1.9537
# epoch:1118  d_loss:0.4672  g_loss:1.5075
# epoch:1119  d_loss:0.4913  g_loss:1.9803
# epoch:1120  d_loss:0.4683  g_loss:2.3463
# epoch:1121  d_loss:0.3436  g_loss:2.6161
# epoch:1122  d_loss:0.4004  g_loss:2.3120
# epoch:1123  d_loss:0.5614  g_loss:2.2703
# epoch:1124  d_loss:0.3611  g_loss:2.2018
# epoch:1125  d_loss:0.4967  g_loss:1.8128
# epoch:1126  d_loss:0.3603  g_loss:1.9752
# epoch:1127  d_loss:0.5296  g_loss:1.9000
# epoch:1128  d_loss:0.4629  g_loss:2.7562
# epoch:1129  d_loss:0.3210  g_loss:2.7304
# epoch:1130  d_loss:0.6020  g_loss:2.1738
# epoch:1131  d_loss:0.5014  g_loss:1.8411
# epoch:1132  d_loss:0.4616  g_loss:2.0362
# epoch:1133  d_loss:0.5117  g_loss:1.7939
# epoch:1134  d_loss:0.4039  g_loss:1.9515
# epoch:1135  d_loss:0.4527  g_loss:2.6516
# epoch:1136  d_loss:0.3735  g_loss:1.8930
# epoch:1137  d_loss:0.2563  g_loss:2.1671
# epoch:1138  d_loss:0.3971  g_loss:1.8938
# epoch:1139  d_loss:0.3469  g_loss:1.8905
# epoch:1140  d_loss:0.4218  g_loss:2.6413
# epoch:1141  d_loss:0.3992  g_loss:2.4392
# epoch:1142  d_loss:0.3135  g_loss:3.0432
# epoch:1143  d_loss:0.4655  g_loss:2.2094
# epoch:1144  d_loss:0.3239  g_loss:1.9412
# epoch:1145  d_loss:0.5179  g_loss:1.9025
# epoch:1146  d_loss:0.3590  g_loss:1.9469
# epoch:1147  d_loss:0.5917  g_loss:2.1543
# epoch:1148  d_loss:0.3337  g_loss:2.4726
# epoch:1149  d_loss:0.4741  g_loss:2.4742
# epoch:1150  d_loss:0.4898  g_loss:2.6833
# epoch:1151  d_loss:0.4089  g_loss:2.6795
# epoch:1152  d_loss:0.5987  g_loss:2.2772
# epoch:1153  d_loss:0.5627  g_loss:2.1135
# epoch:1154  d_loss:0.5145  g_loss:1.5562
# epoch:1155  d_loss:0.3405  g_loss:1.7718
# epoch:1156  d_loss:0.7470  g_loss:1.8121
# epoch:1157  d_loss:0.5105  g_loss:2.1452
# epoch:1158  d_loss:0.6212  g_loss:1.8595
# epoch:1159  d_loss:0.5455  g_loss:2.0769
# epoch:1160  d_loss:0.5352  g_loss:2.2455
# epoch:1161  d_loss:0.4732  g_loss:2.1300
# epoch:1162  d_loss:0.5005  g_loss:1.8279
# epoch:1163  d_loss:0.5739  g_loss:1.9718
# epoch:1164  d_loss:0.3438  g_loss:2.1494
# epoch:1165  d_loss:0.4863  g_loss:1.8040
# epoch:1166  d_loss:0.4313  g_loss:2.0537
# epoch:1167  d_loss:0.4020  g_loss:2.3187
# epoch:1168  d_loss:0.4119  g_loss:2.2191
# epoch:1169  d_loss:0.2861  g_loss:2.3774
# epoch:1170  d_loss:0.3726  g_loss:2.4380
# epoch:1171  d_loss:0.3507  g_loss:2.1199
# epoch:1172  d_loss:0.3033  g_loss:1.5841
# epoch:1173  d_loss:0.2844  g_loss:2.1394
# epoch:1174  d_loss:0.3424  g_loss:2.3018
# epoch:1175  d_loss:0.3210  g_loss:2.4604
# epoch:1176  d_loss:0.3185  g_loss:3.1169
# epoch:1177  d_loss:0.4460  g_loss:2.4676
# epoch:1178  d_loss:0.3902  g_loss:2.3726
# epoch:1179  d_loss:0.3199  g_loss:1.9282
# epoch:1180  d_loss:0.3241  g_loss:2.2393
# epoch:1181  d_loss:0.2970  g_loss:2.5647
# epoch:1182  d_loss:0.3710  g_loss:2.5252
# epoch:1183  d_loss:0.3738  g_loss:2.6279
# epoch:1184  d_loss:0.2791  g_loss:2.0870
# epoch:1185  d_loss:0.3491  g_loss:2.5280
# epoch:1186  d_loss:0.3700  g_loss:2.6756
# epoch:1187  d_loss:0.3096  g_loss:2.3253
# epoch:1188  d_loss:0.2550  g_loss:2.5420
# epoch:1189  d_loss:0.3732  g_loss:1.9586
# epoch:1190  d_loss:0.4253  g_loss:2.1282
# epoch:1191  d_loss:0.3684  g_loss:2.4056
# epoch:1192  d_loss:0.3607  g_loss:2.0617
# ...
# epoch:3425  d_loss:0.4398  g_loss:1.5353
# epoch:3426  d_loss:0.5752  g_loss:1.3242
# epoch:3427  d_loss:0.3734  g_loss:1.8095
# epoch:3428  d_loss:0.2697  g_loss:1.7259
# epoch:3429  d_loss:0.4873  g_loss:2.0806
# epoch:3430  d_loss:0.5400  g_loss:1.8917
# epoch:3431  d_loss:0.3135  g_loss:1.9749
# epoch:3432  d_loss:0.3938  g_loss:1.6823
# epoch:3433  d_loss:0.4368  g_loss:1.5570
# epoch:3434  d_loss:0.5238  g_loss:1.5814
# epoch:3435  d_loss:0.3497  g_loss:1.7507
# epoch:3436  d_loss:0.5854  g_loss:1.7830
# epoch:3437  d_loss:0.3020  g_loss:2.0840
# epoch:3438  d_loss:0.4712  g_loss:1.6789
# epoch:3439  d_loss:0.5371  g_loss:1.6527
# epoch:3440  d_loss:0.4180  g_loss:1.7640
# epoch:3441  d_loss:0.4543  g_loss:1.5281
# epoch:3442  d_loss:0.4061  g_loss:1.8295
# epoch:3443  d_loss:0.3372  g_loss:2.2945
# epoch:3444  d_loss:0.3675  g_loss:2.3272
# epoch:3445  d_loss:0.4230  g_loss:2.3673
# epoch:3446  d_loss:0.4360  g_loss:1.9082
# epoch:3447  d_loss:0.3898  g_loss:2.0224
# epoch:3448  d_loss:0.3440  g_loss:1.5386
# epoch:3449  d_loss:0.4716  g_loss:1.6966
# epoch:3450  d_loss:0.5461  g_loss:1.9451
# epoch:3451  d_loss:0.4846  g_loss:1.6272
# epoch:3452  d_loss:0.4819  g_loss:1.8412
# epoch:3453  d_loss:0.4079  g_loss:1.7597
# epoch:3454  d_loss:0.4795  g_loss:1.5367
# epoch:3455  d_loss:0.4842  g_loss:1.7252
# epoch:3456  d_loss:0.5445  g_loss:1.7266
# epoch:3457  d_loss:0.5132  g_loss:1.5377
# epoch:3458  d_loss:0.4302  g_loss:1.8138
# epoch:3459  d_loss:0.4823  g_loss:1.6002
# epoch:3460  d_loss:0.4048  g_loss:1.9224
# epoch:3461  d_loss:0.5532  g_loss:1.8671
# epoch:3462  d_loss:0.3875  g_loss:1.7974
# epoch:3463  d_loss:0.5153  g_loss:1.6116
# epoch:3464  d_loss:0.4464  g_loss:1.5998
# epoch:3465  d_loss:0.4051  g_loss:1.6145
# epoch:3466  d_loss:0.5104  g_loss:1.7623
# epoch:3467  d_loss:0.4067  g_loss:1.9732
# epoch:3468  d_loss:0.3719  g_loss:2.1951
# epoch:3469  d_loss:0.4784  g_loss:1.9013
# epoch:3470  d_loss:0.3649  g_loss:1.8686
# epoch:3471  d_loss:0.4431  g_loss:1.8661
# epoch:3472  d_loss:0.3670  g_loss:1.9228
# epoch:3473  d_loss:0.4028  g_loss:1.7945
# epoch:3474  d_loss:0.3029  g_loss:2.2011
# epoch:3475  d_loss:0.4525  g_loss:2.3664
# epoch:3476  d_loss:0.5057  g_loss:2.3756
# epoch:3477  d_loss:0.4452  g_loss:2.3142
# epoch:3478  d_loss:0.3430  g_loss:2.1121
# epoch:3479  d_loss:0.5569  g_loss:1.4746
# epoch:3480  d_loss:0.4450  g_loss:1.7168
# epoch:3481  d_loss:0.5344  g_loss:2.0700
# epoch:3482  d_loss:0.5774  g_loss:1.5638
# epoch:3483  d_loss:0.4205  g_loss:1.8936
# epoch:3484  d_loss:0.6084  g_loss:2.0598
# epoch:3485  d_loss:0.5980  g_loss:1.2915
# epoch:3486  d_loss:0.4203  g_loss:1.6814
# epoch:3487  d_loss:0.5770  g_loss:1.5792
# epoch:3488  d_loss:0.5134  g_loss:1.9530
# epoch:3489  d_loss:0.4524  g_loss:2.1894
# epoch:3490  d_loss:0.4196  g_loss:2.4100
# epoch:3491  d_loss:0.5981  g_loss:1.7667
# epoch:3492  d_loss:0.3858  g_loss:1.7866
# epoch:3493  d_loss:0.2943  g_loss:1.6377
# epoch:3494  d_loss:0.4398  g_loss:1.6513
# epoch:3495  d_loss:0.4324  g_loss:1.6742
# epoch:3496  d_loss:0.3921  g_loss:1.9975
# epoch:3497  d_loss:0.4550  g_loss:2.0363
# epoch:3498  d_loss:0.3738  g_loss:2.2251
# epoch:3499  d_loss:0.4058  g_loss:1.9531
# epoch:3500  d_loss:0.3656  g_loss:1.7560
# epoch:3501  d_loss:0.6023  g_loss:1.3419
# epoch:3502  d_loss:0.3799  g_loss:1.6881
# epoch:3503  d_loss:0.3914  g_loss:1.6339
# epoch:3504  d_loss:0.3421  g_loss:2.0780
# epoch:3505  d_loss:0.2623  g_loss:2.4013
# epoch:3506  d_loss:0.5339  g_loss:2.3515
# epoch:3507  d_loss:0.4692  g_loss:1.6253
# epoch:3508  d_loss:0.4931  g_loss:1.7186
# epoch:3509  d_loss:0.5186  g_loss:1.9233
# epoch:3510  d_loss:0.4052  g_loss:2.5138
# epoch:3511  d_loss:0.4027  g_loss:2.2140
# epoch:3512  d_loss:0.5590  g_loss:2.0224
# epoch:3513  d_loss:0.4014  g_loss:2.1398
# epoch:3514  d_loss:0.4302  g_loss:1.3830
# epoch:3515  d_loss:0.5881  g_loss:1.3391
# epoch:3516  d_loss:0.5860  g_loss:1.3597
# epoch:3517  d_loss:0.5131  g_loss:1.7742
# epoch:3518  d_loss:0.5333  g_loss:1.9479
# epoch:3519  d_loss:0.5555  g_loss:2.5007
# epoch:3520  d_loss:0.5107  g_loss:2.2278
# epoch:3521  d_loss:0.6814  g_loss:2.0567
# epoch:3522  d_loss:0.6103  g_loss:1.9635
# epoch:3523  d_loss:0.4744  g_loss:1.5769
# epoch:3524  d_loss:0.4621  g_loss:1.4454
# epoch:3525  d_loss:0.4161  g_loss:1.5969
# epoch:3526  d_loss:0.3891  g_loss:1.4640
# epoch:3527  d_loss:0.4969  g_loss:2.0132
# epoch:3528  d_loss:0.3696  g_loss:1.7670
# epoch:3529  d_loss:0.5509  g_loss:2.3687
# epoch:3530  d_loss:0.4851  g_loss:2.2719
# epoch:3531  d_loss:0.4390  g_loss:2.1976
# epoch:3532  d_loss:0.6602  g_loss:1.7324
# epoch:3533  d_loss:0.6201  g_loss:1.3839
# epoch:3534  d_loss:0.5025  g_loss:1.9829
# epoch:3535  d_loss:0.2922  g_loss:2.1309
# epoch:3536  d_loss:0.4829  g_loss:2.2641
# epoch:3537  d_loss:0.3685  g_loss:2.0229
# epoch:3538  d_loss:0.4440  g_loss:2.0549
# epoch:3539  d_loss:0.6206  g_loss:1.7838
# epoch:3540  d_loss:0.7006  g_loss:1.7033
# epoch:3541  d_loss:0.4947  g_loss:1.8697
# epoch:3542  d_loss:0.3418  g_loss:2.1426
# epoch:3543  d_loss:0.4477  g_loss:2.0523
# epoch:3544  d_loss:0.6323  g_loss:1.7509
# epoch:3545  d_loss:0.4799  g_loss:1.6703
# epoch:3546  d_loss:0.3827  g_loss:1.6966
# epoch:3547  d_loss:0.4461  g_loss:1.8180
# epoch:3548  d_loss:0.4452  g_loss:1.8019
# epoch:3549  d_loss:0.6811  g_loss:1.4271
# epoch:3550  d_loss:0.5077  g_loss:1.4585
# epoch:3551  d_loss:0.4289  g_loss:1.7932
# epoch:3552  d_loss:0.5283  g_loss:1.4897
# epoch:3553  d_loss:0.6065  g_loss:1.4941
# epoch:3554  d_loss:0.4689  g_loss:1.4781
# epoch:3555  d_loss:0.5322  g_loss:1.7329
# epoch:3556  d_loss:0.6477  g_loss:2.2094
# epoch:3557  d_loss:0.5763  g_loss:1.6588
# epoch:3558  d_loss:0.5352  g_loss:1.3518
# epoch:3559  d_loss:0.5146  g_loss:1.4039
# epoch:3560  d_loss:0.6280  g_loss:1.5009
# epoch:3561  d_loss:0.4727  g_loss:1.7492
# epoch:3562  d_loss:0.4929  g_loss:1.7780
# epoch:3563  d_loss:0.6865  g_loss:1.5553
# epoch:3564  d_loss:0.6430  g_loss:1.4769
# epoch:3565  d_loss:0.5453  g_loss:1.3239
# epoch:3566  d_loss:0.5302  g_loss:1.3993
# epoch:3567  d_loss:0.5240  g_loss:1.7045
# epoch:3568  d_loss:0.4829  g_loss:1.9221
# epoch:3569  d_loss:0.5352  g_loss:1.5098
# epoch:3570  d_loss:0.5446  g_loss:1.5677
# epoch:3571  d_loss:0.4178  g_loss:1.8952
# epoch:3572  d_loss:0.5265  g_loss:1.3943
# epoch:3573  d_loss:0.4374  g_loss:1.4724
# epoch:3574  d_loss:0.4999  g_loss:1.5442
# epoch:3575  d_loss:0.5328  g_loss:1.4818
# epoch:3576  d_loss:0.4161  g_loss:1.7465
# epoch:3577  d_loss:0.5260  g_loss:1.5576
# epoch:3578  d_loss:0.4004  g_loss:1.7399
# epoch:3579  d_loss:0.4466  g_loss:1.6113
# epoch:3580  d_loss:0.4941  g_loss:1.6490
# epoch:3581  d_loss:0.4191  g_loss:1.8364
# epoch:3582  d_loss:0.2753  g_loss:2.0049
# epoch:3583  d_loss:0.5097  g_loss:2.3126
# epoch:3584  d_loss:0.5132  g_loss:1.7431
# epoch:3585  d_loss:0.5224  g_loss:1.5604
# epoch:3586  d_loss:0.7166  g_loss:1.3446
# epoch:3587  d_loss:0.4982  g_loss:1.6380
# epoch:3588  d_loss:0.5922  g_loss:1.5879
# epoch:3589  d_loss:0.4607  g_loss:1.7900
# epoch:3590  d_loss:0.5742  g_loss:1.7060
# epoch:3591  d_loss:0.6722  g_loss:1.7956
# epoch:3592  d_loss:0.4346  g_loss:1.8465
# epoch:3593  d_loss:0.4907  g_loss:1.6292
# epoch:3594  d_loss:0.5151  g_loss:1.2656
# epoch:3595  d_loss:0.4192  g_loss:1.4646
# epoch:3596  d_loss:0.4609  g_loss:1.7717
# epoch:3597  d_loss:0.4574  g_loss:1.6720
# epoch:3598  d_loss:0.4270  g_loss:1.8717
# epoch:3599  d_loss:0.5598  g_loss:1.8568
# epoch:3600  d_loss:0.5445  g_loss:1.7092
# epoch:3601  d_loss:0.5667  g_loss:1.5287
# epoch:3602  d_loss:0.5357  g_loss:1.6248
# epoch:3603  d_loss:0.4409  g_loss:1.7702
# epoch:3604  d_loss:0.4398  g_loss:1.7142
# epoch:3605  d_loss:0.5444  g_loss:1.9964
# epoch:3606  d_loss:0.5588  g_loss:1.9458
# epoch:3607  d_loss:0.4809  g_loss:1.6834
# epoch:3608  d_loss:0.4086  g_loss:1.8129
# epoch:3609  d_loss:0.5384  g_loss:1.8116
# epoch:3610  d_loss:0.4003  g_loss:1.4013
# epoch:3611  d_loss:0.4738  g_loss:1.8173
# epoch:3612  d_loss:0.4487  g_loss:2.0166
# epoch:3613  d_loss:0.5227  g_loss:1.7654
# epoch:3614  d_loss:0.6444  g_loss:1.6374
# epoch:3615  d_loss:0.6402  g_loss:1.4957
# epoch:3616  d_loss:0.4744  g_loss:1.4291
# epoch:3617  d_loss:0.6022  g_loss:1.7342
# epoch:3618  d_loss:0.6282  g_loss:1.5640
# epoch:3619  d_loss:0.4056  g_loss:1.4971
# epoch:3620  d_loss:0.5966  g_loss:1.4329
# epoch:3621  d_loss:0.4759  g_loss:1.7241
# epoch:3622  d_loss:0.5432  g_loss:1.7647
# epoch:3623  d_loss:0.6226  g_loss:1.7013
# epoch:3624  d_loss:0.5670  g_loss:1.3550
# epoch:3625  d_loss:0.5327  g_loss:1.3561
# epoch:3626  d_loss:0.4226  g_loss:1.5033
# epoch:3627  d_loss:0.4530  g_loss:1.4455
# epoch:3628  d_loss:0.5003  g_loss:1.4541
# epoch:3629  d_loss:0.4797  g_loss:1.7204
# epoch:3630  d_loss:0.3606  g_loss:1.7750
# epoch:3631  d_loss:0.4944  g_loss:1.4517
# epoch:3632  d_loss:0.3875  g_loss:1.3456
# epoch:3633  d_loss:0.7463  g_loss:1.5162
# epoch:3634  d_loss:0.5103  g_loss:1.4934
# epoch:3635  d_loss:0.6406  g_loss:1.6916
# epoch:3636  d_loss:0.4991  g_loss:1.4890
# epoch:3637  d_loss:0.5997  g_loss:1.9022
# epoch:3638  d_loss:0.4321  g_loss:1.6081
# epoch:3639  d_loss:0.5601  g_loss:1.7363
# epoch:3640  d_loss:0.7551  g_loss:1.3590
# epoch:3641  d_loss:0.4799  g_loss:1.7425
# epoch:3642  d_loss:0.5312  g_loss:1.5321
# epoch:3643  d_loss:0.4981  g_loss:1.4879
# epoch:3644  d_loss:0.6732  g_loss:1.4188
# epoch:3645  d_loss:0.4688  g_loss:1.4291
# epoch:3646  d_loss:0.5177  g_loss:1.4811
# epoch:3647  d_loss:0.5200  g_loss:1.4803
# epoch:3648  d_loss:0.5715  g_loss:1.3942
# epoch:3649  d_loss:0.4986  g_loss:1.6997
# epoch:3650  d_loss:0.5303  g_loss:1.3854
# epoch:3651  d_loss:0.5074  g_loss:1.7314
# epoch:3652  d_loss:0.5252  g_loss:1.6970
# epoch:3653  d_loss:0.3348  g_loss:1.7142
# epoch:3654  d_loss:0.5274  g_loss:1.6160
# epoch:3655  d_loss:0.4711  g_loss:1.4684
# epoch:3656  d_loss:0.5435  g_loss:1.4194
# epoch:3657  d_loss:0.5020  g_loss:1.8412
# epoch:3658  d_loss:0.5298  g_loss:1.5333
# epoch:3659  d_loss:0.3482  g_loss:2.0611
# epoch:3660  d_loss:0.4859  g_loss:2.0750
# epoch:3661  d_loss:0.5578  g_loss:1.5297
# epoch:3662  d_loss:0.6495  g_loss:1.9488
# epoch:3663  d_loss:0.4268  g_loss:1.9361
# epoch:3664  d_loss:0.4126  g_loss:1.9358
# epoch:3665  d_loss:0.4556  g_loss:1.4444
# epoch:3666  d_loss:0.4326  g_loss:1.7024
# epoch:3667  d_loss:0.5455  g_loss:1.4640
# epoch:3668  d_loss:0.4613  g_loss:1.6190
# epoch:3669  d_loss:0.5581  g_loss:1.6488
# epoch:3670  d_loss:0.5352  g_loss:1.7143
# epoch:3671  d_loss:0.5759  g_loss:1.4934
# epoch:3672  d_loss:0.5355  g_loss:1.9844
# epoch:3673  d_loss:0.5587  g_loss:1.2983
# epoch:3674  d_loss:0.4435  g_loss:1.8389
# epoch:3675  d_loss:0.6936  g_loss:1.4232
# epoch:3676  d_loss:0.5675  g_loss:1.8247
# epoch:3677  d_loss:0.5550  g_loss:1.7205
# epoch:3678  d_loss:0.6334  g_loss:1.4755
# epoch:3679  d_loss:0.6558  g_loss:1.5889
# epoch:3680  d_loss:0.5746  g_loss:1.3874
# epoch:3681  d_loss:0.5099  g_loss:1.5069
# epoch:3682  d_loss:0.6187  g_loss:1.3356
# epoch:3683  d_loss:0.6466  g_loss:1.5492
# epoch:3684  d_loss:0.6465  g_loss:1.4232
# epoch:3685  d_loss:0.3754  g_loss:1.6395
# epoch:3686  d_loss:0.4698  g_loss:1.9060
# epoch:3687  d_loss:0.4824  g_loss:1.5177
# epoch:3688  d_loss:0.4832  g_loss:1.5509
# epoch:3689  d_loss:0.5136  g_loss:1.6941
# epoch:3690  d_loss:0.4288  g_loss:1.6475
# epoch:3691  d_loss:0.4151  g_loss:1.6358
# epoch:3692  d_loss:0.4527  g_loss:1.6295
# epoch:3693  d_loss:0.4098  g_loss:1.6504
# epoch:3694  d_loss:0.4535  g_loss:1.7657
# epoch:3695  d_loss:0.3735  g_loss:1.7640
# epoch:3696  d_loss:0.3296  g_loss:2.2864
# epoch:3697  d_loss:0.3762  g_loss:2.1563
# epoch:3698  d_loss:0.3265  g_loss:1.4501
# epoch:3699  d_loss:0.4169  g_loss:1.3480
# epoch:3700  d_loss:0.3291  g_loss:1.8361
# epoch:3701  d_loss:0.4578  g_loss:1.8881
# epoch:3702  d_loss:0.5103  g_loss:1.8332
# epoch:3703  d_loss:0.5604  g_loss:1.6361
# epoch:3704  d_loss:0.5788  g_loss:1.4050
# epoch:3705  d_loss:0.5330  g_loss:1.3431
# epoch:3706  d_loss:0.6647  g_loss:1.9811
# epoch:3707  d_loss:0.4998  g_loss:1.9102
# epoch:3708  d_loss:0.4996  g_loss:1.9058
# epoch:3709  d_loss:0.5758  g_loss:1.7817
# epoch:3710  d_loss:0.5597  g_loss:1.6485
# epoch:3711  d_loss:0.5956  g_loss:1.2076
# epoch:3712  d_loss:0.6906  g_loss:1.2654
# epoch:3713  d_loss:0.5272  g_loss:1.5795
# epoch:3714  d_loss:0.6942  g_loss:1.5418
# epoch:3715  d_loss:0.5863  g_loss:1.6412
# epoch:3716  d_loss:0.6484  g_loss:1.8265
# epoch:3717  d_loss:0.5325  g_loss:1.5753
# epoch:3718  d_loss:0.5289  g_loss:1.8325
# epoch:3719  d_loss:0.4127  g_loss:2.2632
# epoch:3720  d_loss:0.5861  g_loss:2.0211
# epoch:3721  d_loss:0.4528  g_loss:1.6346
# epoch:3722  d_loss:0.4156  g_loss:1.9007
# epoch:3723  d_loss:0.4095  g_loss:1.5938
# epoch:3724  d_loss:0.5216  g_loss:1.9058
# epoch:3725  d_loss:0.4661  g_loss:1.8990
# epoch:3726  d_loss:0.3013  g_loss:2.1248
# epoch:3727  d_loss:0.4494  g_loss:1.7882
# epoch:3728  d_loss:0.3873  g_loss:2.0780
# epoch:3729  d_loss:0.3035  g_loss:1.5339
# epoch:3730  d_loss:0.3076  g_loss:1.8433
# epoch:3731  d_loss:0.3679  g_loss:1.8984
# epoch:3732  d_loss:0.5184  g_loss:1.8630
# epoch:3733  d_loss:0.3076  g_loss:1.7730
# epoch:3734  d_loss:0.3463  g_loss:2.3956
# epoch:3735  d_loss:0.4555  g_loss:2.2022
# epoch:3736  d_loss:0.3749  g_loss:1.9168
# epoch:3737  d_loss:0.3154  g_loss:1.9212
# epoch:3738  d_loss:0.4675  g_loss:1.9539
# epoch:3739  d_loss:0.3550  g_loss:2.1880
# epoch:3740  d_loss:0.5794  g_loss:1.9732
# epoch:3741  d_loss:0.4596  g_loss:1.8965
# epoch:3742  d_loss:0.3428  g_loss:2.0744
# epoch:3743  d_loss:0.4261  g_loss:2.0782
# epoch:3744  d_loss:0.3586  g_loss:2.0286
# epoch:3745  d_loss:0.5092  g_loss:1.7047
# epoch:3746  d_loss:0.5482  g_loss:1.8889
# epoch:3747  d_loss:0.5001  g_loss:1.8958
# epoch:3748  d_loss:0.5140  g_loss:2.0439
# epoch:3749  d_loss:0.6740  g_loss:1.9734
# epoch:3750  d_loss:0.4147  g_loss:2.1517
# epoch:3751  d_loss:0.3637  g_loss:1.6838
# epoch:3752  d_loss:0.4894  g_loss:1.4501
# epoch:3753  d_loss:0.4375  g_loss:2.0476
# epoch:3754  d_loss:0.4633  g_loss:1.9985
# epoch:3755  d_loss:0.4979  g_loss:1.8774
# epoch:3756  d_loss:0.4031  g_loss:1.8913
# epoch:3757  d_loss:0.4036  g_loss:1.5774
# epoch:3758  d_loss:0.4359  g_loss:1.6571
# epoch:3759  d_loss:0.5000  g_loss:1.6624
# epoch:3760  d_loss:0.5488  g_loss:1.8428
# epoch:3761  d_loss:0.5696  g_loss:1.5861
# epoch:3762  d_loss:0.4750  g_loss:1.6183
# epoch:3763  d_loss:0.6038  g_loss:1.6432
# epoch:3764  d_loss:0.5756  g_loss:1.8034
# epoch:3765  d_loss:0.5207  g_loss:1.4886
# epoch:3766  d_loss:0.3544  g_loss:1.9834
# epoch:3767  d_loss:0.5423  g_loss:1.5978
# epoch:3768  d_loss:0.4391  g_loss:1.1506
# epoch:3769  d_loss:0.5318  g_loss:1.6014
# epoch:3770  d_loss:0.5120  g_loss:1.2622
# epoch:3771  d_loss:0.5514  g_loss:1.6103
# epoch:3772  d_loss:0.4084  g_loss:2.0280
# epoch:3773  d_loss:0.3133  g_loss:2.5149
# epoch:3774  d_loss:0.4886  g_loss:2.1594
# epoch:3775  d_loss:0.6170  g_loss:1.3390
# epoch:3776  d_loss:0.4503  g_loss:1.6318
# epoch:3777  d_loss:0.3427  g_loss:1.8183
# epoch:3778  d_loss:0.4546  g_loss:2.1061
# epoch:3779  d_loss:0.4123  g_loss:2.3221
# epoch:3780  d_loss:0.3921  g_loss:2.2989
# epoch:3781  d_loss:0.4640  g_loss:2.1516
# epoch:3782  d_loss:0.5406  g_loss:1.8129
# epoch:3783  d_loss:0.4166  g_loss:1.8191
# epoch:3784  d_loss:0.4654  g_loss:1.4884
# epoch:3785  d_loss:0.3883  g_loss:1.5313
# epoch:3786  d_loss:0.4260  g_loss:2.0656
# epoch:3787  d_loss:0.3641  g_loss:2.3421
# epoch:3788  d_loss:0.3986  g_loss:2.0667
# epoch:3789  d_loss:0.3876  g_loss:1.9216
# epoch:3790  d_loss:0.4226  g_loss:1.9483
# epoch:3791  d_loss:0.6545  g_loss:1.8146
# epoch:3792  d_loss:0.4310  g_loss:1.9834
# epoch:3793  d_loss:0.4469  g_loss:2.2786
# epoch:3794  d_loss:0.6054  g_loss:1.7549
# epoch:3795  d_loss:0.5775  g_loss:1.6106
# epoch:3796  d_loss:0.3970  g_loss:1.8772
# epoch:3797  d_loss:0.4794  g_loss:1.7743
# epoch:3798  d_loss:0.6262  g_loss:1.8258
# epoch:3799  d_loss:0.4693  g_loss:1.8521
# epoch:3800  d_loss:0.5522  g_loss:1.3724
# epoch:3801  d_loss:0.4993  g_loss:1.4888
# epoch:3802  d_loss:0.6191  g_loss:1.4954
# epoch:3803  d_loss:0.3819  g_loss:1.7795
# epoch:3804  d_loss:0.3623  g_loss:2.1172
# epoch:3805  d_loss:0.4849  g_loss:2.2603
# epoch:3806  d_loss:0.6271  g_loss:1.7138
# epoch:3807  d_loss:0.3239  g_loss:2.0363
# epoch:3808  d_loss:0.5019  g_loss:1.5529
# epoch:3809  d_loss:0.4826  g_loss:1.6860
# epoch:3810  d_loss:0.2570  g_loss:1.8177
# epoch:3811  d_loss:0.4526  g_loss:2.1827
# epoch:3812  d_loss:0.4351  g_loss:2.1729
# epoch:3813  d_loss:0.3226  g_loss:1.8529
# epoch:3814  d_loss:0.2404  g_loss:2.3316
