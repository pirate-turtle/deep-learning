# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint,EarlyStopping

import pandas as pd
import numpy
import os
import tensorflow as tf

# seed 값 설정
numpy.random.seed(3)
tf.random.set_seed(3)

# %% [markdown]
# ## 1. 데이터 읽어오기

# %%
df_pre = pd.read_csv('./dataset/wine.csv', header=None)
df_pre.shape
# Out:
# (6497, 13)

# %%
# 6497 * 0.15
df = df_pre.sample(frac=0.15)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 975 entries, 3553 to 1668
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       975 non-null    float64
#  1   1       975 non-null    float64
#  2   2       975 non-null    float64
#  3   3       975 non-null    float64
#  4   4       975 non-null    float64
#  5   5       975 non-null    float64
#  6   6       975 non-null    float64
#  7   7       975 non-null    float64
#  8   8       975 non-null    float64
#  9   9       975 non-null    float64
#  10  10      975 non-null    float64
#  11  11      975 non-null    int64
#  12  12      975 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 106.6 KB

# %% [markdown]
# ## 2. 데이터 전처리

# %%
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %% [markdown]
# ## 3. 모델 설계

# %%
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## 4. 모델 컴파일

# %%
model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# %% [markdown]
# ## 5. 학습

# %%
# 모델 저장 폴더 만들기
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# 모델 업데이트 및 저장
# monitor = val_loss => 모델의 성능이 좋은것만 가져오겠다
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
# loss가 줄어들다가 갑자기 튀면 연속 100번까지는 봐주고 101번부터는 중단시켜!
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 1.60391, saving model to ./model/01-1.6039.hdf5
#
# Epoch 00002: val_loss improved from 1.60391 to 1.16100, saving model to ./model/02-1.1610.hdf5
#
# Epoch 00003: val_loss improved from 1.16100 to 0.78195, saving model to ./model/03-0.7819.hdf5
#
# Epoch 00004: val_loss improved from 0.78195 to 0.76963, saving model to ./model/04-0.7696.hdf5
#
# Epoch 00005: val_loss improved from 0.76963 to 0.74016, saving model to ./model/05-0.7402.hdf5
#
# Epoch 00006: val_loss improved from 0.74016 to 0.58141, saving model to ./model/06-0.5814.hdf5
#
# Epoch 00007: val_loss did not improve from 0.58141
#
# Epoch 00008: val_loss did not improve from 0.58141
#
# Epoch 00009: val_loss did not improve from 0.58141
#
# Epoch 00010: val_loss improved from 0.58141 to 0.54629, saving model to ./model/10-0.5463.hdf5
#
# Epoch 00011: val_loss improved from 0.54629 to 0.48836, saving model to ./model/11-0.4884.hdf5
#
# Epoch 00012: val_loss improved from 0.48836 to 0.43474, saving model to ./model/12-0.4347.hdf5
#
# Epoch 00013: val_loss improved from 0.43474 to 0.40417, saving model to ./model/13-0.4042.hdf5
#
# Epoch 00014: val_loss improved from 0.40417 to 0.39435, saving model to ./model/14-0.3943.hdf5
#
# Epoch 00015: val_loss improved from 0.39435 to 0.37773, saving model to ./model/15-0.3777.hdf5
#
# Epoch 00016: val_loss improved from 0.37773 to 0.35593, saving model to ./model/16-0.3559.hdf5
#
# Epoch 00017: val_loss improved from 0.35593 to 0.34311, saving model to ./model/17-0.3431.hdf5
#
# Epoch 00018: val_loss improved from 0.34311 to 0.33695, saving model to ./model/18-0.3369.hdf5
#
# Epoch 00019: val_loss improved from 0.33695 to 0.32876, saving model to ./model/19-0.3288.hdf5
#
# Epoch 00020: val_loss improved from 0.32876 to 0.31490, saving model to ./model/20-0.3149.hdf5
#
# Epoch 00021: val_loss improved from 0.31490 to 0.29838, saving model to ./model/21-0.2984.hdf5
#
# Epoch 00022: val_loss improved from 0.29838 to 0.28204, saving model to ./model/22-0.2820.hdf5
#
# Epoch 00023: val_loss improved from 0.28204 to 0.26895, saving model to ./model/23-0.2689.hdf5
#
# Epoch 00024: val_loss improved from 0.26895 to 0.25829, saving model to ./model/24-0.2583.hdf5
#
# Epoch 00025: val_loss improved from 0.25829 to 0.24877, saving model to ./model/25-0.2488.hdf5
#
# Epoch 00026: val_loss improved from 0.24877 to 0.23984, saving model to ./model/26-0.2398.hdf5
#
# Epoch 00027: val_loss improved from 0.23984 to 0.23175, saving model to ./model/27-0.2317.hdf5
#
# Epoch 00028: val_loss improved from 0.23175 to 0.22445, saving model to ./model/28-0.2244.hdf5
#
# Epoch 00029: val_loss improved from 0.22445 to 0.21654, saving model to ./model/29-0.2165.hdf5
#
# Epoch 00030: val_loss improved from 0.21654 to 0.20871, saving model to ./model/30-0.2087.hdf5
#
# Epoch 00031: val_loss improved from 0.20871 to 0.20099, saving model to ./model/31-0.2010.hdf5
#
# Epoch 00032: val_loss improved from 0.20099 to 0.19334, saving model to ./model/32-0.1933.hdf5
#
# Epoch 00033: val_loss improved from 0.19334 to 0.18888, saving model to ./model/33-0.1889.hdf5
#
# Epoch 00034: val_loss improved from 0.18888 to 0.18652, saving model to ./model/34-0.1865.hdf5
#
# Epoch 00035: val_loss improved from 0.18652 to 0.18485, saving model to ./model/35-0.1848.hdf5
#
# Epoch 00036: val_loss improved from 0.18485 to 0.18294, saving model to ./model/36-0.1829.hdf5
#
# Epoch 00037: val_loss improved from 0.18294 to 0.18139, saving model to ./model/37-0.1814.hdf5
#
# Epoch 00038: val_loss improved from 0.18139 to 0.18066, saving model to ./model/38-0.1807.hdf5
#
# Epoch 00039: val_loss improved from 0.18066 to 0.18054, saving model to ./model/39-0.1805.hdf5
#
# Epoch 00040: val_loss improved from 0.18054 to 0.18034, saving model to ./model/40-0.1803.hdf5
#
# Epoch 00041: val_loss improved from 0.18034 to 0.17915, saving model to ./model/41-0.1792.hdf5
#
# Epoch 00042: val_loss improved from 0.17915 to 0.17699, saving model to ./model/42-0.1770.hdf5
#
# Epoch 00043: val_loss improved from 0.17699 to 0.17503, saving model to ./model/43-0.1750.hdf5
#
# Epoch 00044: val_loss improved from 0.17503 to 0.17304, saving model to ./model/44-0.1730.hdf5
#
# Epoch 00045: val_loss improved from 0.17304 to 0.17138, saving model to ./model/45-0.1714.hdf5
#
# Epoch 00046: val_loss improved from 0.17138 to 0.17002, saving model to ./model/46-0.1700.hdf5
#
# Epoch 00047: val_loss improved from 0.17002 to 0.16896, saving model to ./model/47-0.1690.hdf5
#
# Epoch 00048: val_loss improved from 0.16896 to 0.16834, saving model to ./model/48-0.1683.hdf5
#
# Epoch 00049: val_loss improved from 0.16834 to 0.16817, saving model to ./model/49-0.1682.hdf5
#
# Epoch 00050: val_loss did not improve from 0.16817
#
# Epoch 00051: val_loss improved from 0.16817 to 0.16797, saving model to ./model/51-0.1680.hdf5
#
# Epoch 00052: val_loss improved from 0.16797 to 0.16732, saving model to ./model/52-0.1673.hdf5
#
# Epoch 00053: val_loss improved from 0.16732 to 0.16669, saving model to ./model/53-0.1667.hdf5
#
# Epoch 00054: val_loss improved from 0.16669 to 0.16595, saving model to ./model/54-0.1659.hdf5
#
# Epoch 00055: val_loss improved from 0.16595 to 0.16505, saving model to ./model/55-0.1651.hdf5
#
# Epoch 00056: val_loss improved from 0.16505 to 0.16428, saving model to ./model/56-0.1643.hdf5
#
# Epoch 00057: val_loss improved from 0.16428 to 0.16365, saving model to ./model/57-0.1637.hdf5
#
# Epoch 00058: val_loss improved from 0.16365 to 0.16312, saving model to ./model/58-0.1631.hdf5
#
# Epoch 00059: val_loss improved from 0.16312 to 0.16301, saving model to ./model/59-0.1630.hdf5
#
# Epoch 00060: val_loss improved from 0.16301 to 0.16282, saving model to ./model/60-0.1628.hdf5
#
# Epoch 00061: val_loss improved from 0.16282 to 0.16239, saving model to ./model/61-0.1624.hdf5
#
# Epoch 00062: val_loss improved from 0.16239 to 0.16176, saving model to ./model/62-0.1618.hdf5
#
# Epoch 00063: val_loss improved from 0.16176 to 0.16087, saving model to ./model/63-0.1609.hdf5
#
# Epoch 00064: val_loss improved from 0.16087 to 0.16037, saving model to ./model/64-0.1604.hdf5
#
# Epoch 00065: val_loss improved from 0.16037 to 0.15977, saving model to ./model/65-0.1598.hdf5
#
# Epoch 00066: val_loss improved from 0.15977 to 0.15912, saving model to ./model/66-0.1591.hdf5
#
# Epoch 00067: val_loss improved from 0.15912 to 0.15878, saving model to ./model/67-0.1588.hdf5
#
# Epoch 00068: val_loss improved from 0.15878 to 0.15855, saving model to ./model/68-0.1586.hdf5
#
# Epoch 00069: val_loss improved from 0.15855 to 0.15815, saving model to ./model/69-0.1581.hdf5
#
# Epoch 00070: val_loss improved from 0.15815 to 0.15757, saving model to ./model/70-0.1576.hdf5
#
# Epoch 00071: val_loss improved from 0.15757 to 0.15709, saving model to ./model/71-0.1571.hdf5
#
# Epoch 00072: val_loss improved from 0.15709 to 0.15685, saving model to ./model/72-0.1569.hdf5
#
# Epoch 00073: val_loss did not improve from 0.15685
#
# Epoch 00074: val_loss improved from 0.15685 to 0.15669, saving model to ./model/74-0.1567.hdf5
#
# Epoch 00075: val_loss improved from 0.15669 to 0.15634, saving model to ./model/75-0.1563.hdf5
#
# Epoch 00076: val_loss improved from 0.15634 to 0.15564, saving model to ./model/76-0.1556.hdf5
#
# Epoch 00077: val_loss improved from 0.15564 to 0.15503, saving model to ./model/77-0.1550.hdf5
#
# Epoch 00078: val_loss improved from 0.15503 to 0.15466, saving model to ./model/78-0.1547.hdf5
#
# Epoch 00079: val_loss improved from 0.15466 to 0.15438, saving model to ./model/79-0.1544.hdf5
#
# Epoch 00080: val_loss improved from 0.15438 to 0.15400, saving model to ./model/80-0.1540.hdf5
#
# Epoch 00081: val_loss improved from 0.15400 to 0.15348, saving model to ./model/81-0.1535.hdf5
#
# Epoch 00082: val_loss improved from 0.15348 to 0.15305, saving model to ./model/82-0.1531.hdf5
#
# Epoch 00083: val_loss improved from 0.15305 to 0.15272, saving model to ./model/83-0.1527.hdf5
#
# Epoch 00084: val_loss improved from 0.15272 to 0.15245, saving model to ./model/84-0.1524.hdf5
#
# Epoch 00085: val_loss improved from 0.15245 to 0.15233, saving model to ./model/85-0.1523.hdf5
#
# Epoch 00086: val_loss improved from 0.15233 to 0.15217, saving model to ./model/86-0.1522.hdf5
#
# Epoch 00087: val_loss improved from 0.15217 to 0.15167, saving model to ./model/87-0.1517.hdf5
#
# Epoch 00088: val_loss improved from 0.15167 to 0.15086, saving model to ./model/88-0.1509.hdf5
#
# Epoch 00089: val_loss improved from 0.15086 to 0.15053, saving model to ./model/89-0.1505.hdf5
#
# Epoch 00090: val_loss improved from 0.15053 to 0.15025, saving model to ./model/90-0.1503.hdf5
# Epoch 00091: val_loss improved from 0.15025 to 0.14996, saving model to ./model/91-0.1500.hdf5
#
# Epoch 00092: val_loss improved from 0.14996 to 0.14976, saving model to ./model/92-0.1498.hdf5
#
# Epoch 00093: val_loss did not improve from 0.14976
#
# Epoch 00094: val_loss did not improve from 0.14976
#
# Epoch 00095: val_loss did not improve from 0.14976
#
# Epoch 00096: val_loss improved from 0.14976 to 0.14924, saving model to ./model/96-0.1492.hdf5
#
# Epoch 00097: val_loss improved from 0.14924 to 0.14829, saving model to ./model/97-0.1483.hdf5
#
# Epoch 00098: val_loss improved from 0.14829 to 0.14792, saving model to ./model/98-0.1479.hdf5
#
# Epoch 00099: val_loss improved from 0.14792 to 0.14779, saving model to ./model/99-0.1478.hdf5
#
# Epoch 00100: val_loss improved from 0.14779 to 0.14729, saving model to ./model/100-0.1473.hdf5
#
# Epoch 00101: val_loss improved from 0.14729 to 0.14676, saving model to ./model/101-0.1468.hdf5
#
# Epoch 00102: val_loss improved from 0.14676 to 0.14665, saving model to ./model/102-0.1467.hdf5
#
# Epoch 00103: val_loss did not improve from 0.14665
#
# Epoch 00104: val_loss improved from 0.14665 to 0.14652, saving model to ./model/104-0.1465.hdf5
#
# Epoch 00105: val_loss improved from 0.14652 to 0.14578, saving model to ./model/105-0.1458.hdf5
#
# Epoch 00106: val_loss improved from 0.14578 to 0.14504, saving model to ./model/106-0.1450.hdf5
#
# Epoch 00107: val_loss improved from 0.14504 to 0.14462, saving model to ./model/107-0.1446.hdf5
#
# Epoch 00108: val_loss improved from 0.14462 to 0.14447, saving model to ./model/108-0.1445.hdf5
#
# Epoch 00109: val_loss improved from 0.14447 to 0.14436, saving model to ./model/109-0.1444.hdf5
#
# Epoch 00110: val_loss did not improve from 0.14436
#
# Epoch 00111: val_loss did not improve from 0.14436
#
# Epoch 00112: val_loss did not improve from 0.14436
#
# Epoch 00113: val_loss improved from 0.14436 to 0.14435, saving model to ./model/113-0.1444.hdf5
#
# Epoch 00114: val_loss improved from 0.14435 to 0.14415, saving model to ./model/114-0.1442.hdf5
#
# Epoch 00115: val_loss improved from 0.14415 to 0.14370, saving model to ./model/115-0.1437.hdf5
#
# Epoch 00116: val_loss improved from 0.14370 to 0.14316, saving model to ./model/116-0.1432.hdf5
#
# Epoch 00117: val_loss improved from 0.14316 to 0.14283, saving model to ./model/117-0.1428.hdf5
#
# Epoch 00118: val_loss improved from 0.14283 to 0.14250, saving model to ./model/118-0.1425.hdf5
#
# Epoch 00119: val_loss improved from 0.14250 to 0.14226, saving model to ./model/119-0.1423.hdf5
#
# Epoch 00120: val_loss improved from 0.14226 to 0.14217, saving model to ./model/120-0.1422.hdf5
#
# Epoch 00121: val_loss improved from 0.14217 to 0.14195, saving model to ./model/121-0.1419.hdf5
#
# Epoch 00122: val_loss improved from 0.14195 to 0.14177, saving model to ./model/122-0.1418.hdf5
#
# Epoch 00123: val_loss improved from 0.14177 to 0.14129, saving model to ./model/123-0.1413.hdf5
#
# Epoch 00124: val_loss improved from 0.14129 to 0.14096, saving model to ./model/124-0.1410.hdf5
#
# Epoch 00125: val_loss improved from 0.14096 to 0.14067, saving model to ./model/125-0.1407.hdf5
#
# Epoch 00126: val_loss improved from 0.14067 to 0.14042, saving model to ./model/126-0.1404.hdf5
#
# Epoch 00127: val_loss improved from 0.14042 to 0.14038, saving model to ./model/127-0.1404.hdf5
#
# Epoch 00128: val_loss improved from 0.14038 to 0.14035, saving model to ./model/128-0.1404.hdf5
#
# Epoch 00129: val_loss improved from 0.14035 to 0.14025, saving model to ./model/129-0.1403.hdf5
#
# Epoch 00130: val_loss did not improve from 0.14025
#
# Epoch 00131: val_loss did not improve from 0.14025
#
# Epoch 00132: val_loss did not improve from 0.14025
#
# Epoch 00133: val_loss did not improve from 0.14025
#
# Epoch 00134: val_loss did not improve from 0.14025
#
# Epoch 00135: val_loss improved from 0.14025 to 0.14018, saving model to ./model/135-0.1402.hdf5
#
# Epoch 00136: val_loss improved from 0.14018 to 0.13989, saving model to ./model/136-0.1399.hdf5
#
# Epoch 00137: val_loss improved from 0.13989 to 0.13963, saving model to ./model/137-0.1396.hdf5
#
# Epoch 00138: val_loss improved from 0.13963 to 0.13927, saving model to ./model/138-0.1393.hdf5
#
# Epoch 00139: val_loss improved from 0.13927 to 0.13880, saving model to ./model/139-0.1388.hdf5
#
# Epoch 00140: val_loss improved from 0.13880 to 0.13836, saving model to ./model/140-0.1384.hdf5
#
# Epoch 00141: val_loss improved from 0.13836 to 0.13795, saving model to ./model/141-0.1379.hdf5
#
# Epoch 00142: val_loss improved from 0.13795 to 0.13765, saving model to ./model/142-0.1377.hdf5
#
# Epoch 00143: val_loss improved from 0.13765 to 0.13740, saving model to ./model/143-0.1374.hdf5
#
# Epoch 00144: val_loss improved from 0.13740 to 0.13724, saving model to ./model/144-0.1372.hdf5
#
# Epoch 00145: val_loss improved from 0.13724 to 0.13715, saving model to ./model/145-0.1372.hdf5
#
# Epoch 00146: val_loss improved from 0.13715 to 0.13714, saving model to ./model/146-0.1371.hdf5
#
# Epoch 00147: val_loss improved from 0.13714 to 0.13696, saving model to ./model/147-0.1370.hdf5
#
# Epoch 00148: val_loss improved from 0.13696 to 0.13669, saving model to ./model/148-0.1367.hdf5
#
# Epoch 00149: val_loss improved from 0.13669 to 0.13636, saving model to ./model/149-0.1364.hdf5
#
# Epoch 00150: val_loss did not improve from 0.13636
#
# Epoch 00151: val_loss did not improve from 0.13636
#
# Epoch 00152: val_loss did not improve from 0.13636
#
# Epoch 00153: val_loss improved from 0.13636 to 0.13561, saving model to ./model/153-0.1356.hdf5
#
# Epoch 00154: val_loss improved from 0.13561 to 0.13499, saving model to ./model/154-0.1350.hdf5
#
# Epoch 00155: val_loss improved from 0.13499 to 0.13478, saving model to ./model/155-0.1348.hdf5
#
# Epoch 00156: val_loss improved from 0.13478 to 0.13463, saving model to ./model/156-0.1346.hdf5
#
# Epoch 00157: val_loss did not improve from 0.13463
#
# Epoch 00158: val_loss did not improve from 0.13463
#
# Epoch 00159: val_loss did not improve from 0.13463
#
# Epoch 00160: val_loss improved from 0.13463 to 0.13394, saving model to ./model/160-0.1339.hdf5
#
# Epoch 00161: val_loss improved from 0.13394 to 0.13356, saving model to ./model/161-0.1336.hdf5
#
# Epoch 00162: val_loss improved from 0.13356 to 0.13327, saving model to ./model/162-0.1333.hdf5
#
# Epoch 00163: val_loss improved from 0.13327 to 0.13301, saving model to ./model/163-0.1330.hdf5
#
# Epoch 00164: val_loss improved from 0.13301 to 0.13288, saving model to ./model/164-0.1329.hdf5
#
# Epoch 00165: val_loss did not improve from 0.13288
#
# Epoch 00166: val_loss did not improve from 0.13288
#
# Epoch 00167: val_loss improved from 0.13288 to 0.13244, saving model to ./model/167-0.1324.hdf5
#
# Epoch 00168: val_loss improved from 0.13244 to 0.13181, saving model to ./model/168-0.1318.hdf5
#
# Epoch 00169: val_loss improved from 0.13181 to 0.13140, saving model to ./model/169-0.1314.hdf5
#
# Epoch 00170: val_loss improved from 0.13140 to 0.13114, saving model to ./model/170-0.1311.hdf5
#
# Epoch 00171: val_loss improved from 0.13114 to 0.13105, saving model to ./model/171-0.1310.hdf5
#
# Epoch 00172: val_loss did not improve from 0.13105
#
# Epoch 00173: val_loss did not improve from 0.13105
#
# Epoch 00174: val_loss improved from 0.13105 to 0.13071, saving model to ./model/174-0.1307.hdf5
#
# Epoch 00175: val_loss improved from 0.13071 to 0.12989, saving model to ./model/175-0.1299.hdf5
#
# Epoch 00176: val_loss improved from 0.12989 to 0.12952, saving model to ./model/176-0.1295.hdf5
#
# Epoch 00177: val_loss improved from 0.12952 to 0.12934, saving model to ./model/177-0.1293.hdf5
#
# Epoch 00178: val_loss improved from 0.12934 to 0.12913, saving model to ./model/178-0.1291.hdf5
#
# Epoch 00179: val_loss improved from 0.12913 to 0.12900, saving model to ./model/179-0.1290.hdf5
#
# Epoch 00180: val_loss did not improve from 0.12900
#
# Epoch 00181: val_loss did not improve from 0.12900
#
# Epoch 00182: val_loss improved from 0.12900 to 0.12827, saving model to ./model/182-0.1283.hdf5
#
# Epoch 00183: val_loss improved from 0.12827 to 0.12769, saving model to ./model/183-0.1277.hdf5
#
# Epoch 00184: val_loss improved from 0.12769 to 0.12741, saving model to ./model/184-0.1274.hdf5
#
# Epoch 00185: val_loss improved from 0.12741 to 0.12735, saving model to ./model/185-0.1273.hdf5
#
# Epoch 00186: val_loss did not improve from 0.12735
#
# Epoch 00187: val_loss improved from 0.12735 to 0.12695, saving model to ./model/187-0.1269.hdf5
#
# Epoch 00188: val_loss improved from 0.12695 to 0.12648, saving model to ./model/188-0.1265.hdf5
#
# Epoch 00189: val_loss improved from 0.12648 to 0.12630, saving model to ./model/189-0.1263.hdf5
# Epoch 00190: val_loss improved from 0.12630 to 0.12620, saving model to ./model/190-0.1262.hdf5
#
# Epoch 00191: val_loss did not improve from 0.12620
#
# Epoch 00192: val_loss improved from 0.12620 to 0.12615, saving model to ./model/192-0.1262.hdf5
#
# Epoch 00193: val_loss improved from 0.12615 to 0.12562, saving model to ./model/193-0.1256.hdf5
#
# Epoch 00194: val_loss improved from 0.12562 to 0.12535, saving model to ./model/194-0.1253.hdf5
#
# Epoch 00195: val_loss improved from 0.12535 to 0.12520, saving model to ./model/195-0.1252.hdf5
#
# Epoch 00196: val_loss improved from 0.12520 to 0.12454, saving model to ./model/196-0.1245.hdf5
#
# Epoch 00197: val_loss improved from 0.12454 to 0.12413, saving model to ./model/197-0.1241.hdf5
#
# Epoch 00198: val_loss improved from 0.12413 to 0.12396, saving model to ./model/198-0.1240.hdf5
#
# Epoch 00199: val_loss did not improve from 0.12396
#
# Epoch 00200: val_loss did not improve from 0.12396
#
# Epoch 00201: val_loss did not improve from 0.12396
#
# Epoch 00202: val_loss improved from 0.12396 to 0.12333, saving model to ./model/202-0.1233.hdf5
#
# Epoch 00203: val_loss improved from 0.12333 to 0.12285, saving model to ./model/203-0.1229.hdf5
#
# Epoch 00204: val_loss improved from 0.12285 to 0.12222, saving model to ./model/204-0.1222.hdf5
#
# Epoch 00205: val_loss improved from 0.12222 to 0.12197, saving model to ./model/205-0.1220.hdf5
#
# Epoch 00206: val_loss did not improve from 0.12197
#
# Epoch 00207: val_loss did not improve from 0.12197
#
# Epoch 00208: val_loss improved from 0.12197 to 0.12195, saving model to ./model/208-0.1220.hdf5
#
# Epoch 00209: val_loss improved from 0.12195 to 0.12154, saving model to ./model/209-0.1215.hdf5
#
# Epoch 00210: val_loss improved from 0.12154 to 0.12124, saving model to ./model/210-0.1212.hdf5
#
# Epoch 00211: val_loss improved from 0.12124 to 0.12102, saving model to ./model/211-0.1210.hdf5
#
# Epoch 00212: val_loss improved from 0.12102 to 0.12044, saving model to ./model/212-0.1204.hdf5
#
# Epoch 00213: val_loss improved from 0.12044 to 0.12010, saving model to ./model/213-0.1201.hdf5
#
# Epoch 00214: val_loss improved from 0.12010 to 0.12006, saving model to ./model/214-0.1201.hdf5
#
# Epoch 00215: val_loss improved from 0.12006 to 0.11980, saving model to ./model/215-0.1198.hdf5
#
# Epoch 00216: val_loss improved from 0.11980 to 0.11954, saving model to ./model/216-0.1195.hdf5
#
# Epoch 00217: val_loss improved from 0.11954 to 0.11937, saving model to ./model/217-0.1194.hdf5
#
# Epoch 00218: val_loss improved from 0.11937 to 0.11915, saving model to ./model/218-0.1191.hdf5
#
# Epoch 00219: val_loss improved from 0.11915 to 0.11880, saving model to ./model/219-0.1188.hdf5
#
# Epoch 00220: val_loss improved from 0.11880 to 0.11874, saving model to ./model/220-0.1187.hdf5
#
# Epoch 00221: val_loss did not improve from 0.11874
#
# Epoch 00222: val_loss improved from 0.11874 to 0.11806, saving model to ./model/222-0.1181.hdf5
#
# Epoch 00223: val_loss improved from 0.11806 to 0.11760, saving model to ./model/223-0.1176.hdf5
#
# Epoch 00224: val_loss improved from 0.11760 to 0.11755, saving model to ./model/224-0.1176.hdf5
#
# Epoch 00225: val_loss improved from 0.11755 to 0.11744, saving model to ./model/225-0.1174.hdf5
#
# Epoch 00226: val_loss improved from 0.11744 to 0.11719, saving model to ./model/226-0.1172.hdf5
#
# Epoch 00227: val_loss improved from 0.11719 to 0.11702, saving model to ./model/227-0.1170.hdf5
#
# Epoch 00228: val_loss improved from 0.11702 to 0.11665, saving model to ./model/228-0.1166.hdf5
#
# Epoch 00229: val_loss improved from 0.11665 to 0.11634, saving model to ./model/229-0.1163.hdf5
#
# Epoch 00230: val_loss improved from 0.11634 to 0.11606, saving model to ./model/230-0.1161.hdf5
#
# Epoch 00231: val_loss improved from 0.11606 to 0.11573, saving model to ./model/231-0.1157.hdf5
#
# Epoch 00232: val_loss improved from 0.11573 to 0.11535, saving model to ./model/232-0.1154.hdf5
#
# Epoch 00233: val_loss improved from 0.11535 to 0.11519, saving model to ./model/233-0.1152.hdf5
#
# Epoch 00234: val_loss improved from 0.11519 to 0.11485, saving model to ./model/234-0.1148.hdf5
#
# Epoch 00235: val_loss improved from 0.11485 to 0.11467, saving model to ./model/235-0.1147.hdf5
#
# Epoch 00236: val_loss improved from 0.11467 to 0.11453, saving model to ./model/236-0.1145.hdf5
#
# Epoch 00237: val_loss did not improve from 0.11453
#
# Epoch 00238: val_loss did not improve from 0.11453
#
# Epoch 00239: val_loss did not improve from 0.11453
#
# Epoch 00240: val_loss improved from 0.11453 to 0.11395, saving model to ./model/240-0.1140.hdf5
#
# Epoch 00241: val_loss improved from 0.11395 to 0.11351, saving model to ./model/241-0.1135.hdf5
#
# Epoch 00242: val_loss improved from 0.11351 to 0.11329, saving model to ./model/242-0.1133.hdf5
#
# Epoch 00243: val_loss improved from 0.11329 to 0.11329, saving model to ./model/243-0.1133.hdf5
#
# Epoch 00244: val_loss did not improve from 0.11329
#
# Epoch 00245: val_loss improved from 0.11329 to 0.11321, saving model to ./model/245-0.1132.hdf5
#
# Epoch 00246: val_loss improved from 0.11321 to 0.11242, saving model to ./model/246-0.1124.hdf5
#
# Epoch 00247: val_loss improved from 0.11242 to 0.11211, saving model to ./model/247-0.1121.hdf5
#
# Epoch 00248: val_loss did not improve from 0.11211
#
# Epoch 00249: val_loss did not improve from 0.11211
#
# Epoch 00250: val_loss did not improve from 0.11211
#
# Epoch 00251: val_loss improved from 0.11211 to 0.11129, saving model to ./model/251-0.1113.hdf5
#
# Epoch 00252: val_loss improved from 0.11129 to 0.11110, saving model to ./model/252-0.1111.hdf5
#
# Epoch 00253: val_loss improved from 0.11110 to 0.11085, saving model to ./model/253-0.1108.hdf5
#
# Epoch 00254: val_loss improved from 0.11085 to 0.11058, saving model to ./model/254-0.1106.hdf5
#
# Epoch 00255: val_loss did not improve from 0.11058
#
# Epoch 00256: val_loss did not improve from 0.11058
#
# Epoch 00257: val_loss improved from 0.11058 to 0.10974, saving model to ./model/257-0.1097.hdf5
#
# Epoch 00258: val_loss improved from 0.10974 to 0.10909, saving model to ./model/258-0.1091.hdf5
#
# Epoch 00259: val_loss improved from 0.10909 to 0.10871, saving model to ./model/259-0.1087.hdf5
#
# Epoch 00260: val_loss did not improve from 0.10871
#
# Epoch 00261: val_loss did not improve from 0.10871
#
# Epoch 00262: val_loss improved from 0.10871 to 0.10822, saving model to ./model/262-0.1082.hdf5
#
# Epoch 00263: val_loss improved from 0.10822 to 0.10808, saving model to ./model/263-0.1081.hdf5
#
# Epoch 00264: val_loss improved from 0.10808 to 0.10778, saving model to ./model/264-0.1078.hdf5
#
# Epoch 00265: val_loss improved from 0.10778 to 0.10763, saving model to ./model/265-0.1076.hdf5
#
# Epoch 00266: val_loss did not improve from 0.10763
#
# Epoch 00267: val_loss did not improve from 0.10763
#
# Epoch 00268: val_loss improved from 0.10763 to 0.10725, saving model to ./model/268-0.1072.hdf5
#
# Epoch 00269: val_loss improved from 0.10725 to 0.10704, saving model to ./model/269-0.1070.hdf5
#
# Epoch 00270: val_loss improved from 0.10704 to 0.10653, saving model to ./model/270-0.1065.hdf5
#
# Epoch 00271: val_loss improved from 0.10653 to 0.10582, saving model to ./model/271-0.1058.hdf5
#
# Epoch 00272: val_loss improved from 0.10582 to 0.10555, saving model to ./model/272-0.1055.hdf5
#
# Epoch 00273: val_loss did not improve from 0.10555
#
# Epoch 00274: val_loss did not improve from 0.10555
#
# Epoch 00275: val_loss did not improve from 0.10555
#
# Epoch 00276: val_loss improved from 0.10555 to 0.10472, saving model to ./model/276-0.1047.hdf5
#
# Epoch 00277: val_loss improved from 0.10472 to 0.10414, saving model to ./model/277-0.1041.hdf5
#
# Epoch 00278: val_loss did not improve from 0.10414
#
# Epoch 00279: val_loss did not improve from 0.10414
#
# Epoch 00280: val_loss did not improve from 0.10414
#
# Epoch 00281: val_loss did not improve from 0.10414
#
# Epoch 00282: val_loss improved from 0.10414 to 0.10414, saving model to ./model/282-0.1041.hdf5
#
# Epoch 00283: val_loss improved from 0.10414 to 0.10366, saving model to ./model/283-0.1037.hdf5
#
# Epoch 00284: val_loss did not improve from 0.10366
#
# Epoch 00285: val_loss did not improve from 0.10366
#
# Epoch 00286: val_loss improved from 0.10366 to 0.10245, saving model to ./model/286-0.1025.hdf5
#
# Epoch 00287: val_loss improved from 0.10245 to 0.10206, saving model to ./model/287-0.1021.hdf5
#
# Epoch 00288: val_loss improved from 0.10206 to 0.10185, saving model to ./model/288-0.1018.hdf5
#
# Epoch 00289: val_loss did not improve from 0.10185
#
# Epoch 00290: val_loss improved from 0.10185 to 0.10166, saving model to ./model/290-0.1017.hdf5
#
# Epoch 00291: val_loss improved from 0.10166 to 0.10112, saving model to ./model/291-0.1011.hdf5
#
# Epoch 00292: val_loss improved from 0.10112 to 0.10046, saving model to ./model/292-0.1005.hdf5
# Epoch 00293: val_loss improved from 0.10046 to 0.10019, saving model to ./model/293-0.1002.hdf5
#
# Epoch 00294: val_loss did not improve from 0.10019
#
# Epoch 00295: val_loss did not improve from 0.10019
#
# Epoch 00296: val_loss improved from 0.10019 to 0.09963, saving model to ./model/296-0.0996.hdf5
#
# Epoch 00297: val_loss improved from 0.09963 to 0.09940, saving model to ./model/297-0.0994.hdf5
#
# Epoch 00298: val_loss did not improve from 0.09940
#
# Epoch 00299: val_loss did not improve from 0.09940
#
# Epoch 00300: val_loss improved from 0.09940 to 0.09904, saving model to ./model/300-0.0990.hdf5
#
# Epoch 00301: val_loss improved from 0.09904 to 0.09847, saving model to ./model/301-0.0985.hdf5
#
# Epoch 00302: val_loss improved from 0.09847 to 0.09782, saving model to ./model/302-0.0978.hdf5
#
# Epoch 00303: val_loss improved from 0.09782 to 0.09744, saving model to ./model/303-0.0974.hdf5
#
# Epoch 00304: val_loss improved from 0.09744 to 0.09696, saving model to ./model/304-0.0970.hdf5
#
# Epoch 00305: val_loss did not improve from 0.09696
#
# Epoch 00306: val_loss improved from 0.09696 to 0.09676, saving model to ./model/306-0.0968.hdf5
#
# Epoch 00307: val_loss improved from 0.09676 to 0.09561, saving model to ./model/307-0.0956.hdf5
#
# Epoch 00308: val_loss improved from 0.09561 to 0.09465, saving model to ./model/308-0.0946.hdf5
#
# Epoch 00309: val_loss improved from 0.09465 to 0.09460, saving model to ./model/309-0.0946.hdf5
#
# Epoch 00310: val_loss did not improve from 0.09460
#
# Epoch 00311: val_loss did not improve from 0.09460
#
# Epoch 00312: val_loss did not improve from 0.09460
#
# Epoch 00313: val_loss did not improve from 0.09460
#
# Epoch 00314: val_loss did not improve from 0.09460
#
# Epoch 00315: val_loss did not improve from 0.09460
#
# Epoch 00316: val_loss did not improve from 0.09460
#
# Epoch 00317: val_loss improved from 0.09460 to 0.09439, saving model to ./model/317-0.0944.hdf5
#
# Epoch 00318: val_loss improved from 0.09439 to 0.09379, saving model to ./model/318-0.0938.hdf5
#
# Epoch 00319: val_loss improved from 0.09379 to 0.09290, saving model to ./model/319-0.0929.hdf5
#
# Epoch 00320: val_loss improved from 0.09290 to 0.09249, saving model to ./model/320-0.0925.hdf5
#
# Epoch 00321: val_loss did not improve from 0.09249
#
# Epoch 00322: val_loss did not improve from 0.09249
#
# Epoch 00323: val_loss improved from 0.09249 to 0.09193, saving model to ./model/323-0.0919.hdf5
#
# Epoch 00324: val_loss improved from 0.09193 to 0.09152, saving model to ./model/324-0.0915.hdf5
#
# Epoch 00325: val_loss improved from 0.09152 to 0.09136, saving model to ./model/325-0.0914.hdf5
#
# Epoch 00326: val_loss improved from 0.09136 to 0.09103, saving model to ./model/326-0.0910.hdf5
#
# Epoch 00327: val_loss did not improve from 0.09103
#
# Epoch 00328: val_loss improved from 0.09103 to 0.09085, saving model to ./model/328-0.0908.hdf5
#
# Epoch 00329: val_loss improved from 0.09085 to 0.08991, saving model to ./model/329-0.0899.hdf5
#
# Epoch 00330: val_loss did not improve from 0.08991
#
# Epoch 00331: val_loss improved from 0.08991 to 0.08960, saving model to ./model/331-0.0896.hdf5
#
# Epoch 00332: val_loss did not improve from 0.08960
#
# Epoch 00333: val_loss did not improve from 0.08960
#
# Epoch 00334: val_loss improved from 0.08960 to 0.08894, saving model to ./model/334-0.0889.hdf5
#
# Epoch 00335: val_loss improved from 0.08894 to 0.08873, saving model to ./model/335-0.0887.hdf5
#
# Epoch 00336: val_loss improved from 0.08873 to 0.08852, saving model to ./model/336-0.0885.hdf5
#
# Epoch 00337: val_loss did not improve from 0.08852
#
# Epoch 00338: val_loss did not improve from 0.08852
#
# Epoch 00339: val_loss improved from 0.08852 to 0.08793, saving model to ./model/339-0.0879.hdf5
#
# Epoch 00340: val_loss improved from 0.08793 to 0.08723, saving model to ./model/340-0.0872.hdf5
#
# Epoch 00341: val_loss did not improve from 0.08723
#
# Epoch 00342: val_loss did not improve from 0.08723
#
# Epoch 00343: val_loss did not improve from 0.08723
#
# Epoch 00344: val_loss did not improve from 0.08723
#
# Epoch 00345: val_loss did not improve from 0.08723
#
# Epoch 00346: val_loss improved from 0.08723 to 0.08658, saving model to ./model/346-0.0866.hdf5
#
# Epoch 00347: val_loss improved from 0.08658 to 0.08566, saving model to ./model/347-0.0857.hdf5
#
# Epoch 00348: val_loss improved from 0.08566 to 0.08531, saving model to ./model/348-0.0853.hdf5
#
# Epoch 00349: val_loss did not improve from 0.08531
#
# Epoch 00350: val_loss improved from 0.08531 to 0.08493, saving model to ./model/350-0.0849.hdf5
#
# Epoch 00351: val_loss improved from 0.08493 to 0.08379, saving model to ./model/351-0.0838.hdf5
#
# Epoch 00352: val_loss did not improve from 0.08379
#
# Epoch 00353: val_loss did not improve from 0.08379
#
# Epoch 00354: val_loss did not improve from 0.08379
#
# Epoch 00355: val_loss did not improve from 0.08379
#
# Epoch 00356: val_loss improved from 0.08379 to 0.08292, saving model to ./model/356-0.0829.hdf5
#
# Epoch 00357: val_loss improved from 0.08292 to 0.08281, saving model to ./model/357-0.0828.hdf5
#
# Epoch 00358: val_loss did not improve from 0.08281
#
# Epoch 00359: val_loss did not improve from 0.08281
#
# Epoch 00360: val_loss did not improve from 0.08281
#
# Epoch 00361: val_loss improved from 0.08281 to 0.08233, saving model to ./model/361-0.0823.hdf5
#
# Epoch 00362: val_loss improved from 0.08233 to 0.08113, saving model to ./model/362-0.0811.hdf5
#
# Epoch 00363: val_loss improved from 0.08113 to 0.08071, saving model to ./model/363-0.0807.hdf5
#
# Epoch 00364: val_loss did not improve from 0.08071
#
# Epoch 00365: val_loss did not improve from 0.08071
#
# Epoch 00366: val_loss did not improve from 0.08071
#
# Epoch 00367: val_loss did not improve from 0.08071
#
# Epoch 00368: val_loss did not improve from 0.08071
#
# Epoch 00369: val_loss did not improve from 0.08071
#
# Epoch 00370: val_loss improved from 0.08071 to 0.08040, saving model to ./model/370-0.0804.hdf5
#
# Epoch 00371: val_loss improved from 0.08040 to 0.07945, saving model to ./model/371-0.0794.hdf5
#
# Epoch 00372: val_loss did not improve from 0.07945
#
# Epoch 00373: val_loss improved from 0.07945 to 0.07874, saving model to ./model/373-0.0787.hdf5
#
# Epoch 00374: val_loss improved from 0.07874 to 0.07748, saving model to ./model/374-0.0775.hdf5
#
# Epoch 00375: val_loss improved from 0.07748 to 0.07694, saving model to ./model/375-0.0769.hdf5
#
# Epoch 00376: val_loss did not improve from 0.07694
#
# Epoch 00377: val_loss did not improve from 0.07694
#
# Epoch 00378: val_loss did not improve from 0.07694
#
# Epoch 00379: val_loss did not improve from 0.07694
#
# Epoch 00380: val_loss did not improve from 0.07694
#
# Epoch 00381: val_loss did not improve from 0.07694
#
# Epoch 00382: val_loss did not improve from 0.07694
#
# Epoch 00383: val_loss did not improve from 0.07694
#
# Epoch 00384: val_loss did not improve from 0.07694
#
# Epoch 00385: val_loss did not improve from 0.07694
#
# Epoch 00386: val_loss improved from 0.07694 to 0.07603, saving model to ./model/386-0.0760.hdf5
#
# Epoch 00387: val_loss improved from 0.07603 to 0.07575, saving model to ./model/387-0.0757.hdf5
#
# Epoch 00388: val_loss improved from 0.07575 to 0.07537, saving model to ./model/388-0.0754.hdf5
#
# Epoch 00389: val_loss improved from 0.07537 to 0.07508, saving model to ./model/389-0.0751.hdf5
#
# Epoch 00390: val_loss did not improve from 0.07508
#
# Epoch 00391: val_loss did not improve from 0.07508
#
# Epoch 00392: val_loss did not improve from 0.07508
#
# Epoch 00393: val_loss did not improve from 0.07508
#
# Epoch 00394: val_loss improved from 0.07508 to 0.07504, saving model to ./model/394-0.0750.hdf5
#
# Epoch 00395: val_loss did not improve from 0.07504
#
# Epoch 00396: val_loss improved from 0.07504 to 0.07500, saving model to ./model/396-0.0750.hdf5
#
# Epoch 00397: val_loss improved from 0.07500 to 0.07455, saving model to ./model/397-0.0745.hdf5
#
# Epoch 00398: val_loss improved from 0.07455 to 0.07422, saving model to ./model/398-0.0742.hdf5
#
# Epoch 00399: val_loss improved from 0.07422 to 0.07399, saving model to ./model/399-0.0740.hdf5
#
# Epoch 00400: val_loss did not improve from 0.07399
#
# Epoch 00401: val_loss improved from 0.07399 to 0.07366, saving model to ./model/401-0.0737.hdf5
#
# Epoch 00402: val_loss improved from 0.07366 to 0.07334, saving model to ./model/402-0.0733.hdf5
#
# Epoch 00403: val_loss improved from 0.07334 to 0.07325, saving model to ./model/403-0.0732.hdf5
#
# Epoch 00404: val_loss improved from 0.07325 to 0.07287, saving model to ./model/404-0.0729.hdf5
#
# Epoch 00405: val_loss improved from 0.07287 to 0.07260, saving model to ./model/405-0.0726.hdf5
#
# Epoch 00406: val_loss improved from 0.07260 to 0.07162, saving model to ./model/406-0.0716.hdf5
#
# Epoch 00407: val_loss improved from 0.07162 to 0.07111, saving model to ./model/407-0.0711.hdf5
# Epoch 00408: val_loss improved from 0.07111 to 0.07065, saving model to ./model/408-0.0706.hdf5
#
# Epoch 00409: val_loss did not improve from 0.07065
#
# Epoch 00410: val_loss did not improve from 0.07065
#
# Epoch 00411: val_loss did not improve from 0.07065
#
# Epoch 00412: val_loss did not improve from 0.07065
#
# Epoch 00413: val_loss did not improve from 0.07065
#
# Epoch 00414: val_loss did not improve from 0.07065
#
# Epoch 00415: val_loss did not improve from 0.07065
#
# Epoch 00416: val_loss did not improve from 0.07065
#
# Epoch 00417: val_loss did not improve from 0.07065
#
# Epoch 00418: val_loss did not improve from 0.07065
#
# Epoch 00419: val_loss did not improve from 0.07065
#
# Epoch 00420: val_loss improved from 0.07065 to 0.06967, saving model to ./model/420-0.0697.hdf5
#
# Epoch 00421: val_loss improved from 0.06967 to 0.06901, saving model to ./model/421-0.0690.hdf5
#
# Epoch 00422: val_loss improved from 0.06901 to 0.06878, saving model to ./model/422-0.0688.hdf5
#
# Epoch 00423: val_loss did not improve from 0.06878
#
# Epoch 00424: val_loss improved from 0.06878 to 0.06866, saving model to ./model/424-0.0687.hdf5
#
# Epoch 00425: val_loss did not improve from 0.06866
#
# Epoch 00426: val_loss did not improve from 0.06866
#
# Epoch 00427: val_loss did not improve from 0.06866
#
# Epoch 00428: val_loss did not improve from 0.06866
#
# Epoch 00429: val_loss did not improve from 0.06866
#
# Epoch 00430: val_loss did not improve from 0.06866
#
# Epoch 00431: val_loss improved from 0.06866 to 0.06822, saving model to ./model/431-0.0682.hdf5
#
# Epoch 00432: val_loss improved from 0.06822 to 0.06813, saving model to ./model/432-0.0681.hdf5
#
# Epoch 00433: val_loss did not improve from 0.06813
#
# Epoch 00434: val_loss improved from 0.06813 to 0.06796, saving model to ./model/434-0.0680.hdf5
#
# Epoch 00435: val_loss improved from 0.06796 to 0.06763, saving model to ./model/435-0.0676.hdf5
#
# Epoch 00436: val_loss did not improve from 0.06763
#
# Epoch 00437: val_loss did not improve from 0.06763
#
# Epoch 00438: val_loss did not improve from 0.06763
#
# Epoch 00439: val_loss did not improve from 0.06763
#
# Epoch 00440: val_loss improved from 0.06763 to 0.06741, saving model to ./model/440-0.0674.hdf5
#
# Epoch 00441: val_loss improved from 0.06741 to 0.06710, saving model to ./model/441-0.0671.hdf5
#
# Epoch 00442: val_loss improved from 0.06710 to 0.06674, saving model to ./model/442-0.0667.hdf5
#
# Epoch 00443: val_loss did not improve from 0.06674
#
# Epoch 00444: val_loss improved from 0.06674 to 0.06581, saving model to ./model/444-0.0658.hdf5
#
# Epoch 00445: val_loss improved from 0.06581 to 0.06517, saving model to ./model/445-0.0652.hdf5
#
# Epoch 00446: val_loss improved from 0.06517 to 0.06465, saving model to ./model/446-0.0647.hdf5
#
# Epoch 00447: val_loss did not improve from 0.06465
#
# Epoch 00448: val_loss did not improve from 0.06465
#
# Epoch 00449: val_loss did not improve from 0.06465
#
# Epoch 00450: val_loss did not improve from 0.06465
#
# Epoch 00451: val_loss did not improve from 0.06465
#
# Epoch 00452: val_loss did not improve from 0.06465
#
# Epoch 00453: val_loss did not improve from 0.06465
#
# Epoch 00454: val_loss improved from 0.06465 to 0.06431, saving model to ./model/454-0.0643.hdf5
#
# Epoch 00455: val_loss improved from 0.06431 to 0.06352, saving model to ./model/455-0.0635.hdf5
#
# Epoch 00456: val_loss improved from 0.06352 to 0.06328, saving model to ./model/456-0.0633.hdf5
#
# Epoch 00457: val_loss improved from 0.06328 to 0.06321, saving model to ./model/457-0.0632.hdf5
#
# Epoch 00458: val_loss did not improve from 0.06321
#
# Epoch 00459: val_loss did not improve from 0.06321
#
# Epoch 00460: val_loss did not improve from 0.06321
#
# Epoch 00461: val_loss did not improve from 0.06321
#
# Epoch 00462: val_loss did not improve from 0.06321
#
# Epoch 00463: val_loss did not improve from 0.06321
#
# Epoch 00464: val_loss did not improve from 0.06321
#
# Epoch 00465: val_loss improved from 0.06321 to 0.06237, saving model to ./model/465-0.0624.hdf5
#
# Epoch 00466: val_loss improved from 0.06237 to 0.06212, saving model to ./model/466-0.0621.hdf5
#
# Epoch 00467: val_loss improved from 0.06212 to 0.06189, saving model to ./model/467-0.0619.hdf5
#
# Epoch 00468: val_loss improved from 0.06189 to 0.06188, saving model to ./model/468-0.0619.hdf5
#
# Epoch 00469: val_loss did not improve from 0.06188
#
# Epoch 00470: val_loss improved from 0.06188 to 0.06184, saving model to ./model/470-0.0618.hdf5
#
# Epoch 00471: val_loss improved from 0.06184 to 0.06143, saving model to ./model/471-0.0614.hdf5
#
# Epoch 00472: val_loss did not improve from 0.06143
#
# Epoch 00473: val_loss did not improve from 0.06143
#
# Epoch 00474: val_loss improved from 0.06143 to 0.06143, saving model to ./model/474-0.0614.hdf5
#
# Epoch 00475: val_loss improved from 0.06143 to 0.06132, saving model to ./model/475-0.0613.hdf5
#
# Epoch 00476: val_loss improved from 0.06132 to 0.06101, saving model to ./model/476-0.0610.hdf5
#
# Epoch 00477: val_loss did not improve from 0.06101
#
# Epoch 00478: val_loss improved from 0.06101 to 0.06075, saving model to ./model/478-0.0608.hdf5
#
# Epoch 00479: val_loss improved from 0.06075 to 0.06035, saving model to ./model/479-0.0603.hdf5
#
# Epoch 00480: val_loss improved from 0.06035 to 0.06015, saving model to ./model/480-0.0601.hdf5
#
# Epoch 00481: val_loss did not improve from 0.06015
#
# Epoch 00482: val_loss did not improve from 0.06015
#
# Epoch 00483: val_loss improved from 0.06015 to 0.06009, saving model to ./model/483-0.0601.hdf5
#
# Epoch 00484: val_loss improved from 0.06009 to 0.05978, saving model to ./model/484-0.0598.hdf5
#
# Epoch 00485: val_loss improved from 0.05978 to 0.05950, saving model to ./model/485-0.0595.hdf5
#
# Epoch 00486: val_loss did not improve from 0.05950
#
# Epoch 00487: val_loss improved from 0.05950 to 0.05894, saving model to ./model/487-0.0589.hdf5
#
# Epoch 00488: val_loss did not improve from 0.05894
#
# Epoch 00489: val_loss improved from 0.05894 to 0.05868, saving model to ./model/489-0.0587.hdf5
#
# Epoch 00490: val_loss improved from 0.05868 to 0.05845, saving model to ./model/490-0.0584.hdf5
#
# Epoch 00491: val_loss did not improve from 0.05845
#
# Epoch 00492: val_loss did not improve from 0.05845
#
# Epoch 00493: val_loss did not improve from 0.05845
#
# Epoch 00494: val_loss did not improve from 0.05845
#
# Epoch 00495: val_loss did not improve from 0.05845
#
# Epoch 00496: val_loss did not improve from 0.05845
#
# Epoch 00497: val_loss improved from 0.05845 to 0.05806, saving model to ./model/497-0.0581.hdf5
#
# Epoch 00498: val_loss improved from 0.05806 to 0.05756, saving model to ./model/498-0.0576.hdf5
#
# Epoch 00499: val_loss improved from 0.05756 to 0.05732, saving model to ./model/499-0.0573.hdf5
#
# Epoch 00500: val_loss improved from 0.05732 to 0.05712, saving model to ./model/500-0.0571.hdf5
#
# Epoch 00501: val_loss did not improve from 0.05712
#
# Epoch 00502: val_loss did not improve from 0.05712
#
# Epoch 00503: val_loss improved from 0.05712 to 0.05710, saving model to ./model/503-0.0571.hdf5
#
# Epoch 00504: val_loss improved from 0.05710 to 0.05692, saving model to ./model/504-0.0569.hdf5
#
# Epoch 00505: val_loss did not improve from 0.05692
#
# Epoch 00506: val_loss improved from 0.05692 to 0.05634, saving model to ./model/506-0.0563.hdf5
#
# Epoch 00507: val_loss improved from 0.05634 to 0.05586, saving model to ./model/507-0.0559.hdf5
#
# Epoch 00508: val_loss improved from 0.05586 to 0.05561, saving model to ./model/508-0.0556.hdf5
#
# Epoch 00509: val_loss did not improve from 0.05561
#
# Epoch 00510: val_loss did not improve from 0.05561
#
# Epoch 00511: val_loss did not improve from 0.05561
#
# Epoch 00512: val_loss improved from 0.05561 to 0.05553, saving model to ./model/512-0.0555.hdf5
#
# Epoch 00513: val_loss did not improve from 0.05553
#
# Epoch 00514: val_loss did not improve from 0.05553
#
# Epoch 00515: val_loss did not improve from 0.05553
#
# Epoch 00516: val_loss did not improve from 0.05553
#
# Epoch 00517: val_loss improved from 0.05553 to 0.05529, saving model to ./model/517-0.0553.hdf5
#
# Epoch 00518: val_loss improved from 0.05529 to 0.05506, saving model to ./model/518-0.0551.hdf5
#
# Epoch 00519: val_loss did not improve from 0.05506
#
# Epoch 00520: val_loss improved from 0.05506 to 0.05467, saving model to ./model/520-0.0547.hdf5
#
# Epoch 00521: val_loss improved from 0.05467 to 0.05447, saving model to ./model/521-0.0545.hdf5
#
# Epoch 00522: val_loss improved from 0.05447 to 0.05417, saving model to ./model/522-0.0542.hdf5
#
# Epoch 00523: val_loss improved from 0.05417 to 0.05380, saving model to ./model/523-0.0538.hdf5
# Epoch 00524: val_loss did not improve from 0.05380
#
# Epoch 00525: val_loss improved from 0.05380 to 0.05354, saving model to ./model/525-0.0535.hdf5
#
# Epoch 00526: val_loss improved from 0.05354 to 0.05310, saving model to ./model/526-0.0531.hdf5
#
# Epoch 00527: val_loss improved from 0.05310 to 0.05273, saving model to ./model/527-0.0527.hdf5
#
# Epoch 00528: val_loss did not improve from 0.05273
#
# Epoch 00529: val_loss did not improve from 0.05273
#
# Epoch 00530: val_loss did not improve from 0.05273
#
# Epoch 00531: val_loss improved from 0.05273 to 0.05272, saving model to ./model/531-0.0527.hdf5
#
# Epoch 00532: val_loss did not improve from 0.05272
#
# Epoch 00533: val_loss did not improve from 0.05272
#
# Epoch 00534: val_loss did not improve from 0.05272
#
# Epoch 00535: val_loss did not improve from 0.05272
#
# Epoch 00536: val_loss did not improve from 0.05272
#
# Epoch 00537: val_loss did not improve from 0.05272
#
# Epoch 00538: val_loss did not improve from 0.05272
#
# Epoch 00539: val_loss improved from 0.05272 to 0.05241, saving model to ./model/539-0.0524.hdf5
#
# Epoch 00540: val_loss improved from 0.05241 to 0.05231, saving model to ./model/540-0.0523.hdf5
#
# Epoch 00541: val_loss did not improve from 0.05231
#
# Epoch 00542: val_loss improved from 0.05231 to 0.05159, saving model to ./model/542-0.0516.hdf5
#
# Epoch 00543: val_loss improved from 0.05159 to 0.05141, saving model to ./model/543-0.0514.hdf5
#
# Epoch 00544: val_loss improved from 0.05141 to 0.05138, saving model to ./model/544-0.0514.hdf5
#
# Epoch 00545: val_loss did not improve from 0.05138
#
# Epoch 00546: val_loss did not improve from 0.05138
#
# Epoch 00547: val_loss did not improve from 0.05138
#
# Epoch 00548: val_loss did not improve from 0.05138
#
# Epoch 00549: val_loss did not improve from 0.05138
#
# Epoch 00550: val_loss did not improve from 0.05138
#
# Epoch 00551: val_loss did not improve from 0.05138
#
# Epoch 00552: val_loss did not improve from 0.05138
#
# Epoch 00553: val_loss did not improve from 0.05138
#
# Epoch 00554: val_loss did not improve from 0.05138
#
# Epoch 00555: val_loss did not improve from 0.05138
#
# Epoch 00556: val_loss improved from 0.05138 to 0.05102, saving model to ./model/556-0.0510.hdf5
#
# Epoch 00557: val_loss improved from 0.05102 to 0.05090, saving model to ./model/557-0.0509.hdf5
#
# Epoch 00558: val_loss improved from 0.05090 to 0.05079, saving model to ./model/558-0.0508.hdf5
#
# Epoch 00559: val_loss did not improve from 0.05079
#
# Epoch 00560: val_loss improved from 0.05079 to 0.05061, saving model to ./model/560-0.0506.hdf5
#
# Epoch 00561: val_loss improved from 0.05061 to 0.05040, saving model to ./model/561-0.0504.hdf5
#
# Epoch 00562: val_loss did not improve from 0.05040
#
# Epoch 00563: val_loss did not improve from 0.05040
#
# Epoch 00564: val_loss did not improve from 0.05040
#
# Epoch 00565: val_loss improved from 0.05040 to 0.05035, saving model to ./model/565-0.0503.hdf5
#
# Epoch 00566: val_loss improved from 0.05035 to 0.05028, saving model to ./model/566-0.0503.hdf5
#
# Epoch 00567: val_loss improved from 0.05028 to 0.05023, saving model to ./model/567-0.0502.hdf5
#
# Epoch 00568: val_loss did not improve from 0.05023
#
# Epoch 00569: val_loss improved from 0.05023 to 0.05007, saving model to ./model/569-0.0501.hdf5
#
# Epoch 00570: val_loss did not improve from 0.05007
#
# Epoch 00571: val_loss improved from 0.05007 to 0.04957, saving model to ./model/571-0.0496.hdf5
#
# Epoch 00572: val_loss improved from 0.04957 to 0.04955, saving model to ./model/572-0.0495.hdf5
#
# Epoch 00573: val_loss did not improve from 0.04955
#
# Epoch 00574: val_loss improved from 0.04955 to 0.04776, saving model to ./model/574-0.0478.hdf5
#
# Epoch 00575: val_loss improved from 0.04776 to 0.04703, saving model to ./model/575-0.0470.hdf5
#
# Epoch 00576: val_loss improved from 0.04703 to 0.04702, saving model to ./model/576-0.0470.hdf5
#
# Epoch 00577: val_loss did not improve from 0.04702
#
# Epoch 00578: val_loss did not improve from 0.04702
#
# Epoch 00579: val_loss did not improve from 0.04702
#
# Epoch 00580: val_loss did not improve from 0.04702
#
# Epoch 00581: val_loss did not improve from 0.04702
#
# Epoch 00582: val_loss did not improve from 0.04702
#
# Epoch 00583: val_loss did not improve from 0.04702
#
# Epoch 00584: val_loss did not improve from 0.04702
#
# Epoch 00585: val_loss did not improve from 0.04702
#
# Epoch 00586: val_loss did not improve from 0.04702
#
# Epoch 00587: val_loss did not improve from 0.04702
#
# Epoch 00588: val_loss did not improve from 0.04702
#
# Epoch 00589: val_loss did not improve from 0.04702
#
# Epoch 00590: val_loss did not improve from 0.04702
#
# Epoch 00591: val_loss did not improve from 0.04702
#
# Epoch 00592: val_loss did not improve from 0.04702
#
# Epoch 00593: val_loss did not improve from 0.04702
#
# Epoch 00594: val_loss did not improve from 0.04702
#
# Epoch 00595: val_loss improved from 0.04702 to 0.04678, saving model to ./model/595-0.0468.hdf5
#
# Epoch 00596: val_loss did not improve from 0.04678
#
# Epoch 00597: val_loss did not improve from 0.04678
#
# Epoch 00598: val_loss improved from 0.04678 to 0.04645, saving model to ./model/598-0.0465.hdf5
#
# Epoch 00599: val_loss did not improve from 0.04645
#
# Epoch 00600: val_loss did not improve from 0.04645
#
# Epoch 00601: val_loss did not improve from 0.04645
#
# Epoch 00602: val_loss improved from 0.04645 to 0.04619, saving model to ./model/602-0.0462.hdf5
#
# Epoch 00603: val_loss improved from 0.04619 to 0.04596, saving model to ./model/603-0.0460.hdf5
#
# ...
#
# Epoch 00696: val_loss did not improve from 0.03841
#
# Epoch 00697: val_loss did not improve from 0.03841
#
# Epoch 00698: val_loss did not improve from 0.03841
#
# Epoch 00699: val_loss did not improve from 0.03841
#
# Epoch 00700: val_loss did not improve from 0.03841
#
# Epoch 00701: val_loss did not improve from 0.03841
#
# Epoch 00702: val_loss did not improve from 0.03841
#
# Epoch 00703: val_loss did not improve from 0.03841
#
# Epoch 00704: val_loss did not improve from 0.03841
#
# Epoch 00705: val_loss did not improve from 0.03841
#
# Epoch 00706: val_loss did not improve from 0.03841
#
# Epoch 00707: val_loss did not improve from 0.03841
#
# Epoch 00708: val_loss did not improve from 0.03841
#
# Epoch 00709: val_loss did not improve from 0.03841
#
# Epoch 00710: val_loss improved from 0.03841 to 0.03821, saving model to ./model/710-0.0382.hdf5
#
# Epoch 00711: val_loss did not improve from 0.03821
#
# Epoch 00712: val_loss did not improve from 0.03821
#
# Epoch 00713: val_loss did not improve from 0.03821
#
# Epoch 00714: val_loss did not improve from 0.03821
#
# Epoch 00715: val_loss did not improve from 0.03821
#
# Epoch 00716: val_loss did not improve from 0.03821
#
# Epoch 00717: val_loss improved from 0.03821 to 0.03813, saving model to ./model/717-0.0381.hdf5
#
# Epoch 00718: val_loss did not improve from 0.03813
#
# Epoch 00719: val_loss did not improve from 0.03813
#
# Epoch 00720: val_loss did not improve from 0.03813
#
# Epoch 00721: val_loss improved from 0.03813 to 0.03765, saving model to ./model/721-0.0376.hdf5
#
# Epoch 00722: val_loss did not improve from 0.03765
#
# Epoch 00723: val_loss improved from 0.03765 to 0.03710, saving model to ./model/723-0.0371.hdf5
#
# Epoch 00724: val_loss did not improve from 0.03710
#
# Epoch 00725: val_loss did not improve from 0.03710
#
# Epoch 00726: val_loss did not improve from 0.03710
#
# Epoch 00727: val_loss did not improve from 0.03710
#
# Epoch 00728: val_loss did not improve from 0.03710
#
# Epoch 00729: val_loss did not improve from 0.03710
#
# Epoch 00730: val_loss did not improve from 0.03710
#
# Epoch 00731: val_loss did not improve from 0.03710
#
# Epoch 00732: val_loss did not improve from 0.03710
#
# Epoch 00733: val_loss did not improve from 0.03710
#
# Epoch 00734: val_loss did not improve from 0.03710
#
# Epoch 00735: val_loss did not improve from 0.03710
#
# Epoch 00736: val_loss improved from 0.03710 to 0.03669, saving model to ./model/736-0.0367.hdf5
#
# Epoch 00737: val_loss did not improve from 0.03669
#
# Epoch 00738: val_loss did not improve from 0.03669
#
# Epoch 00739: val_loss did not improve from 0.03669
#
# Epoch 00740: val_loss did not improve from 0.03669
#
# Epoch 00741: val_loss did not improve from 0.03669
#
# Epoch 00742: val_loss did not improve from 0.03669
#
# Epoch 00743: val_loss did not improve from 0.03669
#
# Epoch 00744: val_loss did not improve from 0.03669
#
# Epoch 00745: val_loss did not improve from 0.03669
#
# Epoch 00746: val_loss did not improve from 0.03669
#
# Epoch 00747: val_loss did not improve from 0.03669
#
# Epoch 00748: val_loss did not improve from 0.03669
#
# Epoch 00749: val_loss did not improve from 0.03669
#
# Epoch 00750: val_loss did not improve from 0.03669
#
# Epoch 00751: val_loss improved from 0.03669 to 0.03646, saving model to ./model/751-0.0365.hdf5
#
# Epoch 00752: val_loss did not improve from 0.03646
#
# Epoch 00753: val_loss did not improve from 0.03646
#
# Epoch 00754: val_loss did not improve from 0.03646
#
# Epoch 00755: val_loss did not improve from 0.03646
#
# Epoch 00756: val_loss did not improve from 0.03646
#
# Epoch 00757: val_loss did not improve from 0.03646
#
# Epoch 00758: val_loss did not improve from 0.03646
#
# Epoch 00759: val_loss did not improve from 0.03646
#
# Epoch 00760: val_loss did not improve from 0.03646
#
# Epoch 00761: val_loss did not improve from 0.03646
#
# Epoch 00762: val_loss did not improve from 0.03646
#
# Epoch 00763: val_loss did not improve from 0.03646
#
# Epoch 00764: val_loss improved from 0.03646 to 0.03632, saving model to ./model/764-0.0363.hdf5
#
# Epoch 00765: val_loss did not improve from 0.03632
#
# Epoch 00766: val_loss did not improve from 0.03632
#
# Epoch 00767: val_loss did not improve from 0.03632
#
# Epoch 00768: val_loss did not improve from 0.03632
#
# Epoch 00769: val_loss did not improve from 0.03632
#
# Epoch 00770: val_loss did not improve from 0.03632
#
# Epoch 00771: val_loss did not improve from 0.03632
#
# Epoch 00772: val_loss did not improve from 0.03632
#
# Epoch 00773: val_loss did not improve from 0.03632
#
# Epoch 00774: val_loss did not improve from 0.03632
#
# Epoch 00775: val_loss did not improve from 0.03632
#
# Epoch 00776: val_loss did not improve from 0.03632
#
# Epoch 00777: val_loss did not improve from 0.03632
#
# Epoch 00778: val_loss did not improve from 0.03632
#
# Epoch 00779: val_loss did not improve from 0.03632
#
# Epoch 00780: val_loss did not improve from 0.03632
#
# Epoch 00781: val_loss did not improve from 0.03632
#
# Epoch 00782: val_loss did not improve from 0.03632
#
# Epoch 00783: val_loss did not improve from 0.03632
#
# Epoch 00784: val_loss did not improve from 0.03632
#
# Epoch 00785: val_loss did not improve from 0.03632
#
# Epoch 00786: val_loss did not improve from 0.03632
#
# Epoch 00787: val_loss did not improve from 0.03632
#
# Epoch 00788: val_loss did not improve from 0.03632
#
# Epoch 00789: val_loss did not improve from 0.03632
#
# Epoch 00790: val_loss did not improve from 0.03632
#
# Epoch 00791: val_loss did not improve from 0.03632
#
# Epoch 00792: val_loss did not improve from 0.03632
#
# Epoch 00793: val_loss did not improve from 0.03632
#
# Epoch 00794: val_loss did not improve from 0.03632
#
# Epoch 00795: val_loss did not improve from 0.03632
#
# Epoch 00796: val_loss did not improve from 0.03632
#
# Epoch 00797: val_loss did not improve from 0.03632
#
# Epoch 00798: val_loss did not improve from 0.03632
#
# Epoch 00799: val_loss did not improve from 0.03632
# Epoch 00800: val_loss did not improve from 0.03632
#
# Epoch 00801: val_loss did not improve from 0.03632
#
# Epoch 00802: val_loss did not improve from 0.03632
#
# Epoch 00803: val_loss did not improve from 0.03632
#
# Epoch 00804: val_loss did not improve from 0.03632
#
# Epoch 00805: val_loss did not improve from 0.03632
#
# Epoch 00806: val_loss did not improve from 0.03632
#
# Epoch 00807: val_loss did not improve from 0.03632
#
# Epoch 00808: val_loss did not improve from 0.03632
#
# Epoch 00809: val_loss did not improve from 0.03632
#
# Epoch 00810: val_loss did not improve from 0.03632
#
# Epoch 00811: val_loss did not improve from 0.03632
#
# Epoch 00812: val_loss did not improve from 0.03632
#
# Epoch 00813: val_loss did not improve from 0.03632
#
# Epoch 00814: val_loss did not improve from 0.03632
#
# Epoch 00815: val_loss did not improve from 0.03632
#
# Epoch 00816: val_loss did not improve from 0.03632
#
# Epoch 00817: val_loss did not improve from 0.03632
#
# Epoch 00818: val_loss did not improve from 0.03632
#
# Epoch 00819: val_loss did not improve from 0.03632
#
# Epoch 00820: val_loss did not improve from 0.03632
#
# Epoch 00821: val_loss did not improve from 0.03632
#
# Epoch 00822: val_loss did not improve from 0.03632
#
# Epoch 00823: val_loss improved from 0.03632 to 0.03617, saving model to ./model/823-0.0362.hdf5
#
# Epoch 00824: val_loss did not improve from 0.03617
#
# Epoch 00825: val_loss did not improve from 0.03617
#
# Epoch 00826: val_loss did not improve from 0.03617
#
# Epoch 00827: val_loss did not improve from 0.03617
#
# Epoch 00828: val_loss did not improve from 0.03617
#
# Epoch 00829: val_loss did not improve from 0.03617
#
# Epoch 00830: val_loss did not improve from 0.03617
#
# Epoch 00831: val_loss did not improve from 0.03617
#
# Epoch 00832: val_loss did not improve from 0.03617
#
# Epoch 00833: val_loss did not improve from 0.03617
#
# Epoch 00834: val_loss did not improve from 0.03617
#
# Epoch 00835: val_loss did not improve from 0.03617
#
# Epoch 00836: val_loss did not improve from 0.03617
#
# Epoch 00837: val_loss did not improve from 0.03617
#
# Epoch 00838: val_loss did not improve from 0.03617
#
# Epoch 00839: val_loss did not improve from 0.03617
#
# Epoch 00840: val_loss did not improve from 0.03617
#
# Epoch 00841: val_loss did not improve from 0.03617
#
# Epoch 00842: val_loss did not improve from 0.03617
#
# Epoch 00843: val_loss did not improve from 0.03617
#
# Epoch 00844: val_loss did not improve from 0.03617
#
# Epoch 00845: val_loss did not improve from 0.03617
#
# Epoch 00846: val_loss improved from 0.03617 to 0.03594, saving model to ./model/846-0.0359.hdf5
#
# Epoch 00847: val_loss did not improve from 0.03594
#
# Epoch 00848: val_loss did not improve from 0.03594
#
# Epoch 00849: val_loss did not improve from 0.03594
#
# Epoch 00850: val_loss did not improve from 0.03594
#
# Epoch 00851: val_loss did not improve from 0.03594
#
# Epoch 00852: val_loss did not improve from 0.03594
#
# Epoch 00853: val_loss did not improve from 0.03594
#
# Epoch 00854: val_loss did not improve from 0.03594
#
# Epoch 00855: val_loss did not improve from 0.03594
#
# Epoch 00856: val_loss did not improve from 0.03594
#
# Epoch 00857: val_loss did not improve from 0.03594
#
# Epoch 00858: val_loss did not improve from 0.03594
#
# Epoch 00859: val_loss did not improve from 0.03594
#
# Epoch 00860: val_loss did not improve from 0.03594
#
# Epoch 00861: val_loss did not improve from 0.03594
#
# Epoch 00862: val_loss improved from 0.03594 to 0.03581, saving model to ./model/862-0.0358.hdf5
#
# Epoch 00863: val_loss did not improve from 0.03581
#
# Epoch 00864: val_loss did not improve from 0.03581
#
# Epoch 00865: val_loss did not improve from 0.03581
#
# Epoch 00866: val_loss did not improve from 0.03581
#
# Epoch 00867: val_loss did not improve from 0.03581
#
# Epoch 00868: val_loss did not improve from 0.03581
#
# Epoch 00869: val_loss did not improve from 0.03581
#
# Epoch 00870: val_loss did not improve from 0.03581
#
# Epoch 00871: val_loss did not improve from 0.03581
#
# Epoch 00872: val_loss did not improve from 0.03581
#
# Epoch 00873: val_loss did not improve from 0.03581
#
# Epoch 00874: val_loss did not improve from 0.03581
#
# Epoch 00875: val_loss did not improve from 0.03581
#
# Epoch 00876: val_loss did not improve from 0.03581
#
# Epoch 00877: val_loss did not improve from 0.03581
#
# Epoch 00878: val_loss did not improve from 0.03581
#
# Epoch 00879: val_loss did not improve from 0.03581
#
# Epoch 00880: val_loss did not improve from 0.03581
#
# Epoch 00881: val_loss did not improve from 0.03581
#
# Epoch 00882: val_loss did not improve from 0.03581
#
# Epoch 00883: val_loss did not improve from 0.03581
#
# Epoch 00884: val_loss did not improve from 0.03581
#
# Epoch 00885: val_loss did not improve from 0.03581
#
# Epoch 00886: val_loss did not improve from 0.03581
#
# Epoch 00887: val_loss did not improve from 0.03581
#
# Epoch 00888: val_loss did not improve from 0.03581
#
# Epoch 00889: val_loss did not improve from 0.03581
#
# Epoch 00890: val_loss did not improve from 0.03581
#
# Epoch 00891: val_loss improved from 0.03581 to 0.03550, saving model to ./model/891-0.0355.hdf5
#
# Epoch 00892: val_loss improved from 0.03550 to 0.03539, saving model to ./model/892-0.0354.hdf5
#
# Epoch 00893: val_loss did not improve from 0.03539
#
# Epoch 00894: val_loss did not improve from 0.03539
#
# Epoch 00895: val_loss did not improve from 0.03539
#
# Epoch 00896: val_loss did not improve from 0.03539
#
# Epoch 00897: val_loss did not improve from 0.03539
#
# Epoch 00898: val_loss did not improve from 0.03539
#
# Epoch 00899: val_loss did not improve from 0.03539
#
# Epoch 00900: val_loss did not improve from 0.03539
#
# Epoch 00901: val_loss did not improve from 0.03539
#
# Epoch 00902: val_loss did not improve from 0.03539
#
# Epoch 00903: val_loss did not improve from 0.03539
#
# Epoch 00904: val_loss did not improve from 0.03539
#
# Epoch 00905: val_loss did not improve from 0.03539
#
# Epoch 00906: val_loss did not improve from 0.03539
#
# Epoch 00907: val_loss did not improve from 0.03539
#
# Epoch 00908: val_loss did not improve from 0.03539
#
# Epoch 00909: val_loss did not improve from 0.03539
#
# Epoch 00910: val_loss did not improve from 0.03539
#
# Epoch 00911: val_loss did not improve from 0.03539
#
# Epoch 00912: val_loss did not improve from 0.03539
#
# Epoch 00913: val_loss did not improve from 0.03539
#
# Epoch 00914: val_loss did not improve from 0.03539
#
# Epoch 00915: val_loss did not improve from 0.03539
#
# Epoch 00916: val_loss did not improve from 0.03539
#
# Epoch 00917: val_loss did not improve from 0.03539
#
# Epoch 00918: val_loss did not improve from 0.03539
#
# Epoch 00919: val_loss did not improve from 0.03539
#
# Epoch 00920: val_loss did not improve from 0.03539
#
# Epoch 00921: val_loss did not improve from 0.03539
#
# Epoch 00922: val_loss did not improve from 0.03539
#
# Epoch 00923: val_loss did not improve from 0.03539
#
# Epoch 00924: val_loss did not improve from 0.03539
#
# Epoch 00925: val_loss did not improve from 0.03539
#
# Epoch 00926: val_loss did not improve from 0.03539
#
# Epoch 00927: val_loss did not improve from 0.03539
#
# Epoch 00928: val_loss did not improve from 0.03539
#
# Epoch 00929: val_loss did not improve from 0.03539
#
# Epoch 00930: val_loss did not improve from 0.03539
#
# Epoch 00931: val_loss did not improve from 0.03539
#
# Epoch 00932: val_loss did not improve from 0.03539
#
# Epoch 00933: val_loss did not improve from 0.03539
#
# Epoch 00934: val_loss did not improve from 0.03539
#
# Epoch 00935: val_loss did not improve from 0.03539
#
# Epoch 00936: val_loss did not improve from 0.03539
#
# Epoch 00937: val_loss did not improve from 0.03539
#
# Epoch 00938: val_loss did not improve from 0.03539
#
# Epoch 00939: val_loss did not improve from 0.03539
#
# Epoch 00940: val_loss did not improve from 0.03539
#
# Epoch 00941: val_loss did not improve from 0.03539
#
# Epoch 00942: val_loss did not improve from 0.03539
#
# Epoch 00943: val_loss did not improve from 0.03539
#
# Epoch 00944: val_loss did not improve from 0.03539
#
# Epoch 00945: val_loss did not improve from 0.03539
#
# Epoch 00946: val_loss did not improve from 0.03539
#
# Epoch 00947: val_loss did not improve from 0.03539
#
# Epoch 00948: val_loss did not improve from 0.03539
#
# Epoch 00949: val_loss did not improve from 0.03539
#
# Epoch 00950: val_loss did not improve from 0.03539
#
# Epoch 00951: val_loss did not improve from 0.03539
#
# Epoch 00952: val_loss did not improve from 0.03539
#
# Epoch 00953: val_loss did not improve from 0.03539
#
# Epoch 00954: val_loss did not improve from 0.03539
#
# Epoch 00955: val_loss did not improve from 0.03539
#
# Epoch 00956: val_loss did not improve from 0.03539
# Epoch 00957: val_loss did not improve from 0.03539
#
# Epoch 00958: val_loss did not improve from 0.03539
#
# Epoch 00959: val_loss did not improve from 0.03539
#
# Epoch 00960: val_loss did not improve from 0.03539
#
# Epoch 00961: val_loss did not improve from 0.03539
#
# Epoch 00962: val_loss did not improve from 0.03539
#
# Epoch 00963: val_loss did not improve from 0.03539
#
# Epoch 00964: val_loss did not improve from 0.03539
#
# Epoch 00965: val_loss did not improve from 0.03539
#
# Epoch 00966: val_loss did not improve from 0.03539
#
# Epoch 00967: val_loss did not improve from 0.03539
#
# Epoch 00968: val_loss did not improve from 0.03539
#
# Epoch 00969: val_loss did not improve from 0.03539
#
# Epoch 00970: val_loss did not improve from 0.03539
#
# Epoch 00971: val_loss did not improve from 0.03539
#
# Epoch 00972: val_loss did not improve from 0.03539
#
# Epoch 00973: val_loss did not improve from 0.03539
#
# Epoch 00974: val_loss did not improve from 0.03539
#
# Epoch 00975: val_loss did not improve from 0.03539
#
# Epoch 00976: val_loss did not improve from 0.03539
#
# Epoch 00977: val_loss did not improve from 0.03539
#
# Epoch 00978: val_loss did not improve from 0.03539
#
# Epoch 00979: val_loss did not improve from 0.03539
#
# Epoch 00980: val_loss did not improve from 0.03539
#
# Epoch 00981: val_loss did not improve from 0.03539
#
# Epoch 00982: val_loss did not improve from 0.03539
#
# Epoch 00983: val_loss did not improve from 0.03539
#
# Epoch 00984: val_loss did not improve from 0.03539
#
# Epoch 00985: val_loss did not improve from 0.03539
#
# Epoch 00986: val_loss did not improve from 0.03539
#
# Epoch 00987: val_loss did not improve from 0.03539
#
# Epoch 00988: val_loss did not improve from 0.03539
#
# Epoch 00989: val_loss did not improve from 0.03539
#
# Epoch 00990: val_loss did not improve from 0.03539
#
# Epoch 00991: val_loss did not improve from 0.03539
#
# Epoch 00992: val_loss did not improve from 0.03539
